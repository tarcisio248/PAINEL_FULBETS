# %% [markdown]
# # 📅 Rodada Atual v3 — Probabilidades + EV em Tempo Real
# ### Notebook 2 de 2: Jogos futuros · Prob base · Odds D-2 · Scheduler automático
#
# **Fluxo de uso:**
# ```
# MANHÃ (1x por dia)
#   └── Rodar Células 1→6
#   └── Gera rodada_atual_v3.csv com prob_base SEM odd
#   └── Salva odds_d2 (referência para medir movimento)
#
# 30 MIN ANTES DE CADA JOGO (automático)
#   └── Scheduler (Célula 7) roda em background
#   └── Busca odd atual da API
#   └── Calcula EV = prob_base × odd_atual - 1
#   └── Calcula movimento = odd_d2 - odd_atual
#   └── Atualiza rodada_atual_v3.csv
#   └── Alerta no terminal quando EV > 3%
# ```
#
# **Dependências:**
# - `modelo_v3.pkl` — gerado pelo Notebook 1
# - `elo_ratings.json` — gerado pelo Notebook 1

# %%
import requests, pandas as pd, numpy as np
import time, os, json, pickle, warnings
from datetime import datetime, timedelta
import pytz
warnings.filterwarnings("ignore")

# ── Configuração ──────────────────────────────────────────────────────────────
API_KEY    = "033f6d5fc7b707b144fbd2c28898c1540eb066ee9efea6c038d740ffedeacb5f"
BASE_URL   = "https://api.football-data-api.com"
PKL_FILE   = "modelo_v3.pkl"
ELO_FILE   = "elo_ratings.json"
RODADA_CSV = "rodada_atual_v3.csv"
JANELA     = 10
ELO_HOME   = 50
ELO_BASE   = 1500
EV_MIN     = 0.03        # 3% de edge mínimo
SLEEP      = 0.5
MAX_PAGE   = 300

# Fuso horário (ajuste para o seu)
TZ = pytz.timezone("America/Sao_Paulo")

# ── Ligas e season_ids ────────────────────────────────────────────────────────
LIGAS = {
    "Alemanha_1 Bundesliga":        14968,
    "Alemanha_2 2. Bundesliga":     14931,
    "Alemanha_3 3. Liga":           14977,
    "Australia_1 A-League":         16036,
    "Belgica_1 Pro League":         14937,
    "Bulgaria_1 First League":      15056,
    "Croacia_1 HNL":                15053,
    "Escocia_1 Premiership":        15000,
    "Espanha_1 La Liga":            14956,
    "Espanha_2 Segunda Division":   15066,
    "Franca_1 Ligue 1":             14932,
    "Franca_2 Ligue 2":             14954,
    "Grecia_1 Super League":        15163,
    "Holanda_1 Eredivisie":         14936,
    "Holanda_2 Eerste Divisie":     14987,
    "Hungria_1 NB I":               14963,
    "Inglaterra_1 Premier League":  15050,
    "Inglaterra_2 Championship":    14930,
    "Inglaterra_3 League One":      14934,
    "Italia_1 Serie A":             15068,
    "Italia_2 Serie B":             15632,
    "Portugal_1 Primeira Liga":     15115,
    "Rep_Tcheca_1 Czech Liga":      14973,
    "Turquia_1 Super Lig":          14972,
    "Brasileiro_A Serie A":         16544,
    "Argentina_1 Liga Profesional": 16571,
    "Chile_1 Primera Division":     16615,
    "Colombia_1 Liga BetPlay":      16614,
}

print(f"✅ Configuração carregada | {len(LIGAS)} ligas")
print(f"   EV mínimo: {EV_MIN*100:.0f}% | Janela: N{JANELA}")
# Out:
# ✅ Configuração carregada | 28 ligas
#    EV mínimo: 3% | Janela: N10

# %%
# ── Carregar modelo treinado e ratings ELO ───────────────────────────────────

# Modelo
if not os.path.exists(PKL_FILE):
    raise FileNotFoundError(f"❌ {PKL_FILE} não encontrado. Rode o Notebook 1 primeiro.")
with open(PKL_FILE, "rb") as f:
    modelos = pickle.load(f)
print(f"✅ Modelo carregado: {len(modelos)} mercados")
for label, m in modelos.items():
    print(f"   {m['nome']:<16} AUC={m['auc']:.3f}")

# ELO ratings
if not os.path.exists(ELO_FILE):
    raise FileNotFoundError(f"❌ {ELO_FILE} não encontrado. Rode o Notebook 1 primeiro.")
with open(ELO_FILE, "r") as f:
    elo_ratings = json.load(f)
print(f"\n✅ ELO carregado: {len(elo_ratings)} times")

def get_elo(league, team_id):
    return elo_ratings.get(f"{league}|{str(team_id)}", ELO_BASE)
# Out:
# ✅ Modelo carregado: 6 mercados
#    Back Casa        AUC=0.655
#    Back Fora        AUC=0.649
#    BTTS             AUC=0.513
#    Over 2.5         AUC=0.514
#    Over 0.5 HT      AUC=0.520
#    BTTS HT          AUC=0.513
#
# ✅ ELO carregado: 509 times

# %%
# ── Buscar jogos futuros da API ───────────────────────────────────────────────
# Busca jogos com status != complete (agendados/ao vivo)
# Janela: hoje + próximos 7 dias

def buscar_jogos_futuros(liga_nome, season_id):
    jogos, page = [], 1
    agora  = int(datetime.now(TZ).timestamp())
    limite = agora + 7 * 86400  # 7 dias à frente

    while True:
        try:
            resp = requests.get(
                f"{BASE_URL}/league-matches",
                params={"key": API_KEY, "season_id": season_id,
                        "max_per_page": MAX_PAGE, "page": page},
                timeout=20
            )
            if resp.status_code == 429:
                print("  ⚠️  Rate limit — aguardando 60s...")
                time.sleep(60); continue
            resp.raise_for_status()
            data = resp.json()
        except Exception as e:
            print(f"  ❌ {liga_nome}: {e}"); break

        matches = data.get("data", [])
        if not matches: break

        for m in matches:
            status     = m.get("status", "")
            date_unix  = m.get("date_unix", 0) or 0

            # Só jogos futuros dentro da janela
            if status == "complete": continue
            if date_unix < agora or date_unix > limite: continue

            hid = m.get("homeID")
            aid = m.get("awayID")
            hid = str(int(hid)) if hid is not None else "0"
            aid = str(int(aid)) if aid is not None else "0"

            jogos.append({
                "fixture_id":    str(m.get("id", "")),
                "league":        liga_nome,
                "season_id":     season_id,
                "date_unix":     date_unix,
                "home_id":       hid,
                "away_id":       aid,
                "home_team":     m.get("home_name", ""),
                "away_team":     m.get("away_name", ""),
                "status":        status,
                # Odds D-2 (momento da coleta matinal)
                "odd_home_d2":   m.get("odds_ft_1"),
                "odd_draw_d2":   m.get("odds_ft_x"),
                "odd_away_d2":   m.get("odds_ft_2"),
                "odd_btts_d2":   m.get("odds_btts_yes"),
                "odd_over25_d2": m.get("odds_ft_over25"),
                # XG pré-jogo (disponível da API antes do jogo)
                "xg_home_pre":   m.get("team_a_xg_prematch"),
                "xg_away_pre":   m.get("team_b_xg_prematch"),
                "ppg_home":      m.get("pre_match_home_ppg"),
                "ppg_away":      m.get("pre_match_away_ppg"),
            })

        pager = data.get("pager", {})
        if page >= pager.get("total_pages", 1): break
        page += 1
        time.sleep(SLEEP)
    return jogos

# Executar busca
print("🔍 Buscando jogos futuros (próximos 7 dias)...")
todos = []
for liga_nome, season_id in LIGAS.items():
    jogos = buscar_jogos_futuros(liga_nome, season_id)
    if jogos:
        print(f"  📅 {liga_nome}: {len(jogos)} jogos")
    todos.extend(jogos)
    time.sleep(SLEEP)

df_jogos = pd.DataFrame(todos) if todos else pd.DataFrame()
print(f"\n✅ Total: {len(df_jogos)} jogos nos próximos 7 dias")
if len(df_jogos) > 0:
    df_jogos["datahora"] = pd.to_datetime(df_jogos["date_unix"], unit="s")                               .dt.tz_localize("UTC").dt.tz_convert(TZ)                               .dt.strftime("%Y-%m-%d %H:%M")
    display(df_jogos[["datahora","league","home_team","away_team",
                       "odd_home_d2","odd_away_d2","xg_home_pre","xg_away_pre"]].head(10))
# Out:
# 🔍 Buscando jogos futuros (próximos 7 dias)...
#   📅 Alemanha_1 Bundesliga: 3 jogos
#   📅 Alemanha_2 2. Bundesliga: 3 jogos
#   📅 Alemanha_3 3. Liga: 1 jogos
#   📅 Belgica_1 Pro League: 8 jogos
#   📅 Bulgaria_1 First League: 2 jogos
#   📅 Croacia_1 HNL: 2 jogos
#   📅 Escocia_1 Premiership: 1 jogos
#   📅 Espanha_1 La Liga: 2 jogos
#   📅 Espanha_2 Segunda Division: 8 jogos
#   📅 Franca_1 Ligue 1: 5 jogos
#   📅 Grecia_1 Super League: 7 jogos
#   📅 Holanda_1 Eredivisie: 5 jogos
#   📅 Holanda_2 Eerste Divisie: 5 jogos
#   📅 Hungria_1 NB I: 3 jogos
#   📅 Inglaterra_1 Premier League: 2 jogos
#   📅 Inglaterra_3 League One: 1 jogos
#   📅 Italia_1 Serie A: 4 jogos
#   📅 Italia_2 Serie B: 1 jogos
#   📅 Portugal_1 Primeira Liga: 3 jogos
#   📅 Brasileiro_A Serie A: 6 jogos
#   📅 Argentina_1 Liga Profesional: 8 jogos
#   📅 Colombia_1 Liga BetPlay: 13 jogos
#
# ✅ Total: 93 jogos nos próximos 7 dias
#            datahora                    league           home_team  \
# 0  2026-03-22 11:30     Alemanha_1 Bundesliga            Mainz 05
# 1  2026-03-22 15:30     Alemanha_1 Bundesliga            Augsburg
# 2  2026-03-22 13:30     Alemanha_1 Bundesliga           St. Pauli
# 3  2026-03-22 09:30  Alemanha_2 2. Bundesliga     Preußen Münster
# 4  2026-03-22 09:30  Alemanha_2 2. Bundesliga  Fortuna Düsseldorf
# 5  2026-03-22 09:30  Alemanha_2 2. Bundesliga              Bochum
# 6  2026-03-22 12:30        Alemanha_3 3. Liga        MSV Duisburg
# 7  2026-03-22 14:30      Belgica_1 Pro League      RSC Anderlecht
# 8  2026-03-22 14:30      Belgica_1 Pro League        Sint-Truiden
# 9  2026-03-22 14:30      Belgica_1 Pro League       Zulte-Waregem
#
#               away_team  odd_home_d2  odd_away_d2  xg_home_pre  xg_away_pre
# 0   Eintracht Frankfurt         2.02         2.90         1.56         1.24
# 1             Stuttgart         3.30         2.05         1.41         1.79
# 2              Freiburg         2.80         2.83         1.33         1.17
# 3             Magdeburg         2.95         2.15         1.47         1.73
# 4            Hertha BSC         2.30         3.00         1.46         1.40
# 5         Holstein Kiel         2.03         3.00         1.82         1.19
# 6          1860 München         2.10         2.99         1.72         1.22
# 7         Cercle Brugge         2.06         3.54         1.88         1.46
# 8  Union Saint-Gilloise         3.45         2.07         1.73         1.55
# 9    Sporting Charleroi         2.42         2.49         1.61         1.41

# %%
# ── Buscar features N10 dos times a partir da base histórica ─────────────────
# Pega os últimos N10 jogos de cada time da base histórica
# e calcula as médias que o modelo precisa

RAW_CSV = "raw_2526.csv"

if not os.path.exists(RAW_CSV):
    raise FileNotFoundError(f"❌ {RAW_CSV} não encontrado. Rode o Notebook 1 primeiro.")

df_hist = pd.read_csv(RAW_CSV, dtype={"home_id": str, "away_id": str})
df_hist["date_unix"] = pd.to_numeric(df_hist["date_unix"], errors="coerce")
df_hist = df_hist[df_hist["score_home"].notna()]  # só jogos encerrados
df_hist = df_hist.sort_values("date_unix")

def ultimos_n_jogos(df_hist, team_id, liga, n=10):
    """
    Retorna os últimos N jogos do time (como home ou away) numa liga.
    Considera perspectiva do time: gols_marcados = gols como home OU away.
    """
    mask_h = (df_hist["home_id"] == str(team_id)) & (df_hist["league"] == liga)
    mask_a = (df_hist["away_id"] == str(team_id)) & (df_hist["league"] == liga)

    jogos_h = df_hist[mask_h].copy()
    jogos_h["gols_marc"] = jogos_h["score_home"]
    jogos_h["gols_sof"]  = jogos_h["score_away"]
    jogos_h["gols_ht"]   = jogos_h["score_home_ht"].fillna(0)
    jogos_h["vitoria"]   = (jogos_h["score_home"] > jogos_h["score_away"]).astype(int)
    jogos_h["xg"]        = pd.to_numeric(jogos_h.get("xg_home", 0), errors="coerce").fillna(0)

    jogos_a = df_hist[mask_a].copy()
    jogos_a["gols_marc"] = jogos_a["score_away"]
    jogos_a["gols_sof"]  = jogos_a["score_home"]
    jogos_a["gols_ht"]   = jogos_a["score_away_ht"].fillna(0)
    jogos_a["vitoria"]   = (jogos_a["score_away"] > jogos_a["score_home"]).astype(int)
    jogos_a["xg"]        = pd.to_numeric(jogos_a.get("xg_away", 0), errors="coerce").fillna(0)

    todos = pd.concat([jogos_h, jogos_a]).sort_values("date_unix").tail(n)
    if len(todos) == 0:
        return {}

    total_gols = todos["score_home"] + todos["score_away"]
    return {
        "n_jogos":       len(todos),
        "avg_xg":        todos["xg"].mean(),
        "pct_vitoria":   todos["vitoria"].mean(),
        "gols_marc":     todos["gols_marc"].mean(),
        "gols_sof":      todos["gols_sof"].mean(),
        "gols_ht":       todos["gols_ht"].mean(),
        "pct_btts":      ((todos["score_home"]>0)&(todos["score_away"]>0)).mean(),
        "pct_over25":    (total_gols > 2.5).mean(),
        "pct_over05ht":  ((todos["score_home_ht"].fillna(0)+todos["score_away_ht"].fillna(0))>0.5).mean(),
    }

# Calcular features N10 para cada time dos jogos futuros
print(f"⚙️  Calculando features N{JANELA} para {len(df_jogos)} jogos...")

features_jogos = []
for _, jogo in df_jogos.iterrows():
    fh = ultimos_n_jogos(df_hist, jogo["home_id"], jogo["league"], JANELA)
    fa = ultimos_n_jogos(df_hist, jogo["away_id"], jogo["league"], JANELA)

    # ELO pré-jogo
    elo_h = get_elo(jogo["league"], jogo["home_id"])
    elo_a = get_elo(jogo["league"], jogo["away_id"])

    # PPG
    ppg_h = float(jogo.get("ppg_home") or 0)
    ppg_a = float(jogo.get("ppg_away") or 0)

    # XG pré-jogo
    xg_pre_h = float(jogo.get("xg_home_pre") or 0)
    xg_pre_a = float(jogo.get("xg_away_pre") or 0)

    features_jogos.append({
        "fixture_id":       jogo["fixture_id"],
        # Features do modelo
        "elo_delta":        elo_h + ELO_HOME - elo_a,
        "xg_n10_diff":      fh.get("avg_xg",0)      - fa.get("avg_xg",0),
        "xg_pre_diff":      xg_pre_h                 - xg_pre_a,
        "pct_vit_diff":     fh.get("pct_vitoria",0)  - fa.get("pct_vitoria",0),
        "ppg_diff":         ppg_h                    - ppg_a,
        "gols_marc_diff":   fh.get("gols_marc",0)    - fa.get("gols_marc",0),
        "gols_sof_diff":    fh.get("gols_sof",0)     - fa.get("gols_sof",0),
        # Dados extras para o painel
        "n10_home":         fh.get("n_jogos",0),
        "n10_away":         fa.get("n_jogos",0),
        "elo_home":         elo_h,
        "elo_away":         elo_a,
        "xg_home_n10":      fh.get("avg_xg",0),
        "xg_away_n10":      fa.get("avg_xg",0),
        "pct_vit_home":     fh.get("pct_vitoria",0),
        "pct_vit_away":     fa.get("pct_vitoria",0),
        "gols_marc_home":   fh.get("gols_marc",0),
        "gols_marc_away":   fa.get("gols_marc",0),
        "pct_over25_home":  fh.get("pct_over25",0),
        "pct_over25_away":  fa.get("pct_over25",0),
    })

df_feat_fut = pd.DataFrame(features_jogos)
df_jogos = df_jogos.merge(df_feat_fut, on="fixture_id", how="left")
print(f"✅ Features calculadas")
print(f"   Times sem histórico N{JANELA}: "
      f"{(df_jogos['n10_home']==0).sum() + (df_jogos['n10_away']==0).sum()} times")
display(df_jogos[["home_team","away_team","elo_delta","xg_n10_diff",
                   "xg_pre_diff","pct_vit_diff"]].head(10).round(3))
# Out:
# ⚙️  Calculando features N10 para 93 jogos...
# ✅ Features calculadas
#    Times sem histórico N10: 0 times
#             home_team             away_team  elo_delta  xg_n10_diff  \
# 0            Mainz 05   Eintracht Frankfurt     27.796        0.335
# 1            Augsburg             Stuttgart    -64.778       -0.328
# 2           St. Pauli              Freiburg     -6.223       -0.106
# 3     Preußen Münster             Magdeburg     57.175       -0.540
# 4  Fortuna Düsseldorf            Hertha BSC    -27.782        0.132
# 5              Bochum         Holstein Kiel    155.663        0.212
# 6        MSV Duisburg          1860 München     42.906        0.243
# 7      RSC Anderlecht         Cercle Brugge    122.998       -0.027
# 8        Sint-Truiden  Union Saint-Gilloise      2.453        0.081
# 9       Zulte-Waregem    Sporting Charleroi      6.163       -0.125
#
#    xg_pre_diff  pct_vit_diff
# 0         0.32           0.2
# 1        -0.38          -0.1
# 2         0.16           0.0
# 3        -0.26          -0.2
# 4         0.06           0.2
# 5         0.63           0.0
# 6         0.50          -0.3
# 7         0.42          -0.1
# 8         0.18           0.1
# 9         0.20          -0.2

# %%
# ── Calcular probabilidades BASE (sem odd) ───────────────────────────────────
#
# A prob_base é calculada ANTES de olhar as odds.
# Isso garante que o modelo não fica viciado em odds atuais
# que podem mudar até o kickoff.
#
# A odd só entra no EV final (Célula 7 — scheduler).

FEATURES = ["elo_delta","xg_n10_diff","xg_pre_diff","pct_vit_diff",
            "ppg_diff","gols_marc_diff","gols_sof_diff"]

# Verificar quais jogos têm features completas
mask_ok = df_jogos[FEATURES].notna().all(axis=1)
print(f"Jogos com features completas: {mask_ok.sum()}/{len(df_jogos)}")

X = df_jogos.loc[mask_ok, FEATURES].values

for label, m_info in modelos.items():
    col_prob = m_info["col_prob"]
    scaler   = m_info["scaler"]
    model    = m_info["model"]

    X_sc  = scaler.transform(X)
    probs = model.predict_proba(X_sc)[:,1]
    df_jogos.loc[mask_ok, col_prob] = probs

# Calcular EV pré-jogo com odds D-2 (referência)
# EV definitivo virá do scheduler com odds do kickoff
for label, nome, odd_tipica, col_prob, col_ev in [
    ("label_home_win",  "Back Casa",   1.90, "prob_bc",      "ev_bc_d2"),
    ("label_away_win",  "Back Fora",   2.50, "prob_bf",      "ev_bf_d2"),
    ("label_btts",      "BTTS",        1.85, "prob_btts",    "ev_btts_d2"),
    ("label_over25",    "Over 2.5",    1.80, "prob_over25",  "ev_over25_d2"),
    ("label_over05ht",  "Over 0.5 HT", 1.40, "prob_o05ht",   "ev_o05ht_d2"),
    ("label_btts_ht",   "BTTS HT",     3.50, "prob_btts_ht", "ev_btts_ht_d2"),
]:
    odd_col = {"Back Casa":"odd_home_d2","Back Fora":"odd_away_d2",
               "BTTS":"odd_btts_d2","Over 2.5":"odd_over25_d2",
               "Over 0.5 HT":"odd_over25_d2","BTTS HT":"odd_btts_d2"}.get(nome)
    if odd_col and odd_col in df_jogos.columns:
        odd_vals = pd.to_numeric(df_jogos[odd_col], errors="coerce").fillna(odd_tipica)
        df_jogos[col_ev] = df_jogos[col_prob] * odd_vals - 1
    else:
        df_jogos[col_ev] = df_jogos[col_prob] * odd_tipica - 1

print("\n✅ Probabilidades base calculadas")
print("\n📊 Amostra — jogos com maior EV (Back Casa D-2):")
cols_show = ["datahora","league","home_team","away_team",
             "prob_bc","ev_bc_d2","elo_delta","xg_pre_diff"]
cols_show = [c for c in cols_show if c in df_jogos.columns]
top = df_jogos[cols_show].sort_values("ev_bc_d2", ascending=False).head(10)
display(top.round(3))
# Out:
# Jogos com features completas: 93/93
#
# ✅ Probabilidades base calculadas
#
# 📊 Amostra — jogos com maior EV (Back Casa D-2):
#             datahora                    league          home_team  \
# 39  2026-03-22 14:00     Grecia_1 Super League          Volos NFC
# 5   2026-03-22 09:30  Alemanha_2 2. Bundesliga             Bochum
# 54  2026-03-22 15:15            Hungria_1 NB I           Várda SE
# 8   2026-03-22 14:30      Belgica_1 Pro League       Sint-Truiden
# 71  2026-03-22 16:00      Brasileiro_A Serie A               Remo
# 67  2026-03-22 20:30      Brasileiro_A Serie A        Corinthians
# 51  2026-03-22 12:45  Holanda_2 Eerste Divisie                MVV
# 7   2026-03-22 14:30      Belgica_1 Pro League     RSC Anderlecht
# 18  2026-03-22 11:00             Croacia_1 HNL  Slaven Koprivnica
# 69  2026-03-22 18:30      Brasileiro_A Serie A            Vitória
#
#                away_team  prob_bc  ev_bc_d2  elo_delta  xg_pre_diff
# 39                  PAOK    0.145     0.739   -169.319        -0.14
# 5          Holstein Kiel    0.649     0.317    155.663         0.63
# 54           Ferencváros    0.235     0.267    -39.373        -0.32
# 8   Union Saint-Gilloise    0.350     0.208      2.453         0.18
# 71                 Bahia    0.343     0.199    -50.980         0.46
# 67              Flamengo    0.373     0.176     38.814        -0.03
# 51             Willem II    0.266     0.171    -13.382        -0.23
# 7          Cercle Brugge    0.565     0.164    122.998         0.42
# 18                Osijek    0.540     0.160    116.684         0.34
# 69              Mirassol    0.445     0.158     47.438         0.22

# %%
# ── Salvar rodada_atual_v3.csv ────────────────────────────────────────────────
# Este CSV é carregado pelo painel HTML e atualizado pelo scheduler

df_jogos.to_csv(RODADA_CSV, index=False)
print(f"💾 {RODADA_CSV} salvo!")
print(f"   {len(df_jogos)} jogos | {df_jogos['league'].nunique()} ligas")
print(f"   Prob cols: {[c for c in df_jogos.columns if c.startswith('prob_')]}")
print(f"   EV cols  : {[c for c in df_jogos.columns if c.startswith('ev_')]}")
print()

# Resumo de alertas D-2
print("🚨 ALERTAS D-2 — Jogos com EV > {:.0f}% (usando odds de hoje):".format(EV_MIN*100))
for col_ev, nome in [("ev_bc_d2","Back Casa"),("ev_bf_d2","Back Fora"),
                      ("ev_btts_d2","BTTS"),("ev_over25_d2","Over 2.5")]:
    if col_ev not in df_jogos.columns: continue
    alertas = df_jogos[df_jogos[col_ev] > EV_MIN].sort_values(col_ev, ascending=False)
    if len(alertas) > 0:
        print(f"\n  {nome} ({len(alertas)} jogos):")
        for _, r in alertas.head(5).iterrows():
            print(f"    {r.get('datahora','?')[:16]} | {r['home_team']} vs {r['away_team']}"
                  f" | EV={r[col_ev]*100:+.1f}%"
                  f" | prob={r[col_ev.replace('ev_','prob_').replace('_d2','')]*100:.1f}%"
                  if col_ev.replace('ev_','prob_').replace('_d2','') in r else
                  f"    {r.get('datahora','?')[:16]} | {r['home_team']} vs {r['away_team']}"
                  f" | EV={r[col_ev]*100:+.1f}%")

print("\n✅ Célula 6 concluída — pronto para o scheduler (Célula 7)")
print("   Dica: rodar Célula 7 nos dias de jogo para atualização automática")
# Out:
# 💾 rodada_atual_v3.csv salvo!
#    93 jogos | 22 ligas
#    Prob cols: ['prob_bc', 'prob_bf', 'prob_btts', 'prob_over25', 'prob_o05ht', 'prob_btts_ht']
#    EV cols  : ['ev_bc_d2', 'ev_bf_d2', 'ev_btts_d2', 'ev_over25_d2', 'ev_o05ht_d2', 'ev_btts_ht_d2']
#
# 🚨 ALERTAS D-2 — Jogos com EV > 3% (usando odds de hoje):
#
#   Back Casa (16 jogos):
#     2026-03-22 14:00 | Volos NFC vs PAOK | EV=+73.9% | prob=14.5%
#     2026-03-22 09:30 | Bochum vs Holstein Kiel | EV=+31.7% | prob=64.9%
#     2026-03-22 15:15 | Várda SE vs Ferencváros | EV=+26.7% | prob=23.5%
#     2026-03-22 14:30 | Sint-Truiden vs Union Saint-Gilloise | EV=+20.8% | prob=35.0%
#     2026-03-22 16:00 | Remo vs Bahia | EV=+19.9% | prob=34.3%
#
#   Back Fora (35 jogos):
#     2026-03-22 14:00 | AEK Athens vs Kifisia | EV=+122.7% | prob=11.1%
#     2026-03-23 21:15 | Huracán vs Barracas Central | EV=+86.4% | prob=33.9%
#     2026-03-23 19:00 | Estudiantes vs Central Córdoba SdE | EV=+60.2% | prob=22.2%
#     2026-03-22 14:30 | Club Brugge vs KV Mechelen | EV=+57.5% | prob=15.0%
#     2026-03-22 20:00 | Boca Juniors vs Instituto | EV=+55.4% | prob=29.6%
#
#   BTTS (29 jogos):
#     2026-03-23 21:15 | Huracán vs Barracas Central | EV=+41.0% | prob=54.0%
#     2026-03-25 19:00 | Deportivo Riestra vs San Lorenzo | EV=+39.5% | prob=53.6%
#     2026-03-22 14:00 | Olympiakos Piraeus vs Larissa | EV=+32.3% | prob=54.0%
#     2026-03-23 19:00 | Estudiantes vs Central Córdoba SdE | EV=+29.8% | prob=53.0%
#     2026-03-22 15:30 | Sarmiento vs Aldosivi | EV=+29.3% | prob=53.9%
#
#   Over 2.5 (36 jogos):
#     2026-03-25 19:00 | Deportivo Riestra vs San Lorenzo | EV=+103.6% | prob=50.9%
#     2026-03-22 15:30 | Sarmiento vs Aldosivi | EV=+54.3% | prob=51.4%
#     2026-03-23 21:15 | Huracán vs Barracas Central | EV=+54.0% | prob=51.3%
#     2026-03-22 22:15 | Argentinos Juniors vs Platense | EV=+37.6% | prob=52.7%
#     2026-03-22 20:00 | Boca Juniors vs Instituto | EV=+31.2% | prob=50.5%
#
# ✅ Célula 6 concluída — pronto para o scheduler (Célula 7)
#    Dica: rodar Célula 7 nos dias de jogo para atualização automática

# %%
# ── Scheduler — atualiza odds e EV a cada 30 minutos ─────────────────────────
#
# Como usar:
#   1. Rode esta célula nos dias de jogo
#   2. Ela roda em background no Jupyter
#   3. A cada 30 min busca odds atuais dos jogos que ainda não começaram
#   4. Recalcula EV com a odd do momento
#   5. Alerta no terminal quando EV > EV_MIN
#   6. Pressione o botão ■ (Stop) para parar
#
# Os arquivos rodada_atual_v3.csv são atualizados automaticamente
# O painel HTML lerá a versão mais recente

import threading

INTERVALO_MIN = 30  # minutos entre atualizações
_scheduler_ativo = True

def buscar_odd_atual(fixture_id, season_id):
    """Busca odd atual de um jogo específico via fixture_id."""
    try:
        resp = requests.get(
            f"{BASE_URL}/match",
            params={"key": API_KEY, "match_id": fixture_id},
            timeout=15
        )
        resp.raise_for_status()
        data = resp.json()
        m = data.get("data", {})
        if not m: return {}
        return {
            "odd_home_atual":   m.get("odds_ft_1"),
            "odd_draw_atual":   m.get("odds_ft_x"),
            "odd_away_atual":   m.get("odds_ft_2"),
            "odd_btts_atual":   m.get("odds_btts_yes"),
            "odd_over25_atual": m.get("odds_ft_over25"),
            "status":           m.get("status",""),
        }
    except:
        return {}

def calcular_ev_atual(prob, odd):
    """EV = prob × odd - 1. Retorna None se odd indisponível."""
    if not odd or odd <= 1.0: return None
    return prob * float(odd) - 1

def atualizar_ciclo():
    """Um ciclo completo de atualização de odds e EV."""
    agora_ts = int(datetime.now(TZ).timestamp())
    agora_str = datetime.now(TZ).strftime("%H:%M:%S")

    if not os.path.exists(RODADA_CSV):
        print(f"[{agora_str}] ❌ {RODADA_CSV} não encontrado")
        return

    df = pd.read_csv(RODADA_CSV, dtype={"fixture_id": str})
    # Só jogos que ainda não começaram (30 min de margem)
    pendentes = df[pd.to_numeric(df["date_unix"], errors="coerce") > agora_ts - 1800]

    if len(pendentes) == 0:
        print(f"[{agora_str}] ℹ️  Nenhum jogo pendente")
        return

    print(f"[{agora_str}] 🔄 Atualizando {len(pendentes)} jogos...")
    alertas = []

    for idx, jogo in pendentes.iterrows():
        fid     = str(jogo["fixture_id"])
        sid     = jogo.get("season_id", 0)
        odds_at = buscar_odd_atual(fid, sid)
        if not odds_at: continue
        time.sleep(0.3)

        # Atualizar status
        df.at[idx, "status"] = odds_at.get("status", df.at[idx, "status"])

        # Mapas de prob → odd atual → EV final
        mercado_map = [
            ("prob_bc",      "odd_home_atual",   "ev_bc",      "Back Casa",   "odd_home_d2"),
            ("prob_bf",      "odd_away_atual",   "ev_bf",      "Back Fora",   "odd_away_d2"),
            ("prob_btts",    "odd_btts_atual",   "ev_btts",    "BTTS",        "odd_btts_d2"),
            ("prob_over25",  "odd_over25_atual", "ev_over25",  "Over 2.5",    "odd_over25_d2"),
        ]

        for col_prob, col_odd_at, col_ev, nome, col_odd_d2 in mercado_map:
            if col_prob not in df.columns: continue
            prob     = float(df.at[idx, col_prob] or 0)
            odd_at   = odds_at.get(col_odd_at)
            odd_d2   = float(df.at[idx, col_odd_d2] or 0) if col_odd_d2 in df.columns else 0

            ev = calcular_ev_atual(prob, odd_at)
            if ev is None: continue

            df.at[idx, col_ev]              = ev
            df.at[idx, col_odd_at]          = odd_at

            # Movimento da odd (D-2 vs atual)
            if odd_d2 > 0 and odd_at:
                mov = ((float(odd_at) - odd_d2) / odd_d2) * 100
                df.at[idx, f"mov_{col_odd_at.replace('_atual','')}"] = mov

            # Alerta
            if ev > EV_MIN:
                time_ate = int((float(df.at[idx,"date_unix"]) - agora_ts) / 60)
                alertas.append({
                    "mercado": nome,
                    "jogo":    f"{jogo['home_team']} vs {jogo['away_team']}",
                    "liga":    jogo["league"],
                    "ev":      ev,
                    "prob":    prob,
                    "odd":     odd_at,
                    "min_ate": time_ate,
                    "mov":     ((float(odd_at)-odd_d2)/odd_d2*100) if odd_d2>0 and odd_at else 0,
                })

    df.to_csv(RODADA_CSV, index=False)

    # Exibir alertas
    if alertas:
        print(f"\n{'🚨'*3} ALERTAS DE VALOR {'🚨'*3}")
        alertas.sort(key=lambda x: x["ev"], reverse=True)
        for a in alertas:
            sinal_mov = "📉" if a["mov"] < -2 else "📈" if a["mov"] > 2 else "➡️"
            print(f"  ✅ {a['mercado']:<14} | {a['jogo']}")
            print(f"     Liga: {a['liga']} | Faltam: {a['min_ate']} min")
            print(f"     Prob={a['prob']*100:.1f}% | Odd={a['odd']} | EV={a['ev']*100:+.1f}%")
            print(f"     Movimento odd: {sinal_mov} {a['mov']:+.1f}%")
            print()
    else:
        print(f"[{agora_str}] ℹ️  Nenhum jogo com EV > {EV_MIN*100:.0f}% no momento")

    print(f"[{agora_str}] ✅ CSV atualizado → {RODADA_CSV}")

# ── Loop principal ────────────────────────────────────────────────────────────
print(f"🟢 Scheduler iniciado — atualizando a cada {INTERVALO_MIN} minutos")
print(f"   EV mínimo para alerta: {EV_MIN*100:.0f}%")
print(f"   Pressione ■ (Stop) para parar\n")

# Primeira execução imediata
atualizar_ciclo()

# Loop
ciclo = 0
while _scheduler_ativo:
    time.sleep(INTERVALO_MIN * 60)
    ciclo += 1
    print(f"\n── Ciclo {ciclo} ──────────────────────────────")
    atualizar_ciclo()
# Out:
# 🟢 Scheduler iniciado — atualizando a cada 30 minutos
#    EV mínimo para alerta: 3%
#    Pressione ■ (Stop) para parar
#
# [08:04:37] 🔄 Atualizando 93 jogos...
#
# 🚨🚨🚨 ALERTAS DE VALOR 🚨🚨🚨
#   ✅ Back Fora      | AEK Athens vs Kifisia
#      Liga: Grecia_1 Super League | Faltam: 355 min
#      Prob=11.1% | Odd=20 | EV=+122.7%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Over 2.5       | Deportivo Riestra vs San Lorenzo
#      Liga: Argentina_1 Liga Profesional | Faltam: 4975 min
#      Prob=50.9% | Odd=4 | EV=+103.6%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Fora      | Huracán vs Barracas Central
#      Liga: Argentina_1 Liga Profesional | Faltam: 2230 min
#      Prob=33.9% | Odd=5.5 | EV=+86.4%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Casa      | Volos NFC vs PAOK
#      Liga: Grecia_1 Super League | Faltam: 355 min
#      Prob=14.5% | Odd=12 | EV=+73.9%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Fora      | Estudiantes vs Central Córdoba SdE
#      Liga: Argentina_1 Liga Profesional | Faltam: 2095 min
#      Prob=22.2% | Odd=7.2 | EV=+60.2%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Fora      | Club Brugge vs KV Mechelen
#      Liga: Belgica_1 Pro League | Faltam: 385 min
#      Prob=15.0% | Odd=10.5 | EV=+57.5%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Fora      | Boca Juniors vs Instituto
#      Liga: Argentina_1 Liga Profesional | Faltam: 715 min
#      Prob=29.6% | Odd=5.25 | EV=+55.4%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Over 2.5       | Sarmiento vs Aldosivi
#      Liga: Argentina_1 Liga Profesional | Faltam: 445 min
#      Prob=51.4% | Odd=3 | EV=+54.3%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Over 2.5       | Huracán vs Barracas Central
#      Liga: Argentina_1 Liga Profesional | Faltam: 2230 min
#      Prob=51.3% | Odd=3 | EV=+54.0%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Fora      | Cruzeiro vs Santos
#      Liga: Brasileiro_A Serie A | Faltam: 475 min
#      Prob=30.2% | Odd=4.82 | EV=+45.4%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ BTTS           | Huracán vs Barracas Central
#      Liga: Argentina_1 Liga Profesional | Faltam: 2230 min
#      Prob=54.0% | Odd=2.61 | EV=+41.0%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ BTTS           | Deportivo Riestra vs San Lorenzo
#      Liga: Argentina_1 Liga Profesional | Faltam: 4975 min
#      Prob=53.6% | Odd=2.6 | EV=+39.5%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Over 2.5       | Argentinos Juniors vs Platense
#      Liga: Argentina_1 Liga Profesional | Faltam: 850 min
#      Prob=52.7% | Odd=2.61 | EV=+37.6%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Fora      | Atlético PR vs Coritiba
#      Liga: Brasileiro_A Serie A | Faltam: 475 min
#      Prob=31.7% | Odd=4.32 | EV=+36.9%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Fora      | Fortaleza CEIF vs Deportivo Pasto
#      Liga: Colombia_1 Liga BetPlay | Faltam: 3715 min
#      Prob=42.8% | Odd=3.2 | EV=+36.8%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Fora      | Junior vs Atlético Bucaramanga
#      Liga: Colombia_1 Liga BetPlay | Faltam: 3595 min
#      Prob=36.8% | Odd=3.65 | EV=+34.1%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ BTTS           | Olympiakos Piraeus vs Larissa
#      Liga: Grecia_1 Super League | Faltam: 355 min
#      Prob=54.0% | Odd=2.45 | EV=+32.3%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Casa      | Bochum vs Holstein Kiel
#      Liga: Alemanha_2 2. Bundesliga | Faltam: 85 min
#      Prob=64.9% | Odd=2.03 | EV=+31.7%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Fora      | Como vs Pisa
#      Liga: Italia_1 Serie A | Faltam: 25 min
#      Prob=9.9% | Odd=13.28 | EV=+31.3%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Over 2.5       | Boca Juniors vs Instituto
#      Liga: Argentina_1 Liga Profesional | Faltam: 715 min
#      Prob=50.5% | Odd=2.6 | EV=+31.2%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Over 2.5       | Estudiantes vs Central Córdoba SdE
#      Liga: Argentina_1 Liga Profesional | Faltam: 2095 min
#      Prob=52.4% | Odd=2.5 | EV=+30.9%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ BTTS           | Estudiantes vs Central Córdoba SdE
#      Liga: Argentina_1 Liga Profesional | Faltam: 2095 min
#      Prob=53.0% | Odd=2.45 | EV=+29.8%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Fora      | Jaguares de Córdoba vs Rionegro Águilas
#      Liga: Colombia_1 Liga BetPlay | Faltam: 2175 min
#      Prob=49.4% | Odd=2.62 | EV=+29.3%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ BTTS           | Sarmiento vs Aldosivi
#      Liga: Argentina_1 Liga Profesional | Faltam: 445 min
#      Prob=53.9% | Odd=2.4 | EV=+29.3%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ BTTS           | Argentinos Juniors vs Platense
#      Liga: Argentina_1 Liga Profesional | Faltam: 850 min
#      Prob=52.6% | Odd=2.45 | EV=+28.9%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ BTTS           | AEK Athens vs Kifisia
#      Liga: Grecia_1 Super League | Faltam: 355 min
#      Prob=55.9% | Odd=2.3 | EV=+28.7%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Over 2.5       | Fortaleza CEIF vs Deportivo Pasto
#      Liga: Colombia_1 Liga BetPlay | Faltam: 3715 min
#      Prob=50.8% | Odd=2.5 | EV=+27.1%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Casa      | Várda SE vs Ferencváros
#      Liga: Hungria_1 NB I | Faltam: 430 min
#      Prob=23.5% | Odd=5.4 | EV=+26.7%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Over 2.5       | Boyacá Chicó vs Deportes Tolima
#      Liga: Colombia_1 Liga BetPlay | Faltam: 1915 min
#      Prob=49.9% | Odd=2.5 | EV=+24.7%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Over 2.5       | Independiente Rivadavia vs Rosario Central
#      Liga: Argentina_1 Liga Profesional | Faltam: 850 min
#      Prob=52.1% | Odd=2.38 | EV=+24.0%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ BTTS           | Boca Juniors vs Instituto
#      Liga: Argentina_1 Liga Profesional | Faltam: 715 min
#      Prob=53.8% | Odd=2.3 | EV=+23.8%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Fora      | Sarmiento vs Aldosivi
#      Liga: Argentina_1 Liga Profesional | Faltam: 445 min
#      Prob=32.5% | Odd=3.8 | EV=+23.3%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Over 2.5       | Levadiakos vs Atromitos
#      Liga: Grecia_1 Super League | Faltam: 355 min
#      Prob=56.1% | Odd=2.19 | EV=+22.9%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Over 2.5       | Atlético PR vs Coritiba
#      Liga: Brasileiro_A Serie A | Faltam: 475 min
#      Prob=55.9% | Odd=2.2 | EV=+22.9%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Fora      | Fortuna Düsseldorf vs Hertha BSC
#      Liga: Alemanha_2 2. Bundesliga | Faltam: 85 min
#      Prob=40.6% | Odd=3 | EV=+21.8%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Fora      | Athletic Club Bilbao vs Real Betis
#      Liga: Espanha_1 La Liga | Faltam: 385 min
#      Prob=35.3% | Odd=3.45 | EV=+21.8%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ BTTS           | Boyacá Chicó vs Deportes Tolima
#      Liga: Colombia_1 Liga BetPlay | Faltam: 1915 min
#      Prob=54.7% | Odd=2.22 | EV=+21.5%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Over 2.5       | Botev Vratsa vs Lokomotiv Plovdiv
#      Liga: Bulgaria_1 First League | Faltam: 265 min
#      Prob=51.6% | Odd=2.35 | EV=+21.4%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ BTTS           | CSKA Sofia vs Dobrudzha 1919
#      Liga: Bulgaria_1 First League | Faltam: 115 min
#      Prob=52.8% | Odd=2.3 | EV=+21.3%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Over 2.5       | Burgos CF vs Córdoba
#      Liga: Espanha_2 Segunda Division | Faltam: 115 min
#      Prob=53.7% | Odd=2.25 | EV=+20.9%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Casa      | Sint-Truiden vs Union Saint-Gilloise
#      Liga: Belgica_1 Pro League | Faltam: 385 min
#      Prob=35.0% | Odd=3.45 | EV=+20.8%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ BTTS           | Volos NFC vs PAOK
#      Liga: Grecia_1 Super League | Faltam: 355 min
#      Prob=52.5% | Odd=2.3 | EV=+20.8%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Casa      | Remo vs Bahia
#      Liga: Brasileiro_A Serie A | Faltam: 475 min
#      Prob=34.3% | Odd=3.5 | EV=+19.9%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Over 2.5       | Corinthians vs Flamengo
#      Liga: Brasileiro_A Serie A | Faltam: 745 min
#      Prob=53.3% | Odd=2.25 | EV=+19.9%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Over 2.5       | St. Pauli vs Freiburg
#      Liga: Alemanha_1 Bundesliga | Faltam: 325 min
#      Prob=52.0% | Odd=2.3 | EV=+19.6%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Fora      | Argentinos Juniors vs Platense
#      Liga: Argentina_1 Liga Profesional | Faltam: 850 min
#      Prob=22.6% | Odd=5.3 | EV=+19.6%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Fora      | Internacional vs Chapecoense
#      Liga: Brasileiro_A Serie A | Faltam: 625 min
#      Prob=18.4% | Odd=6.5 | EV=+19.5%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Over 2.5       | Deportivo Pereira vs Cúcuta Deportivo
#      Liga: Colombia_1 Liga BetPlay | Faltam: 3445 min
#      Prob=51.3% | Odd=2.33 | EV=+19.5%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ BTTS           | Como vs Pisa
#      Liga: Italia_1 Serie A | Faltam: 25 min
#      Prob=54.1% | Odd=2.2 | EV=+19.0%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ BTTS           | Estudiantes Río Cuarto vs River Plate
#      Liga: Argentina_1 Liga Profesional | Faltam: 580 min
#      Prob=55.3% | Odd=2.15 | EV=+18.9%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Fora      | Puskás vs Debrecen
#      Liga: Hungria_1 NB I | Faltam: 145 min
#      Prob=36.9% | Odd=3.2 | EV=+18.0%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Over 2.5       | Alianza Petrolera vs Deportivo Cali
#      Liga: Colombia_1 Liga BetPlay | Faltam: 595 min
#      Prob=50.2% | Odd=2.35 | EV=+18.0%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Casa      | Corinthians vs Flamengo
#      Liga: Brasileiro_A Serie A | Faltam: 745 min
#      Prob=37.3% | Odd=3.15 | EV=+17.6%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ BTTS           | Alverca vs Sporting CP
#      Liga: Portugal_1 Primeira Liga | Faltam: 415 min
#      Prob=55.2% | Odd=2.13 | EV=+17.5%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Fora      | Alianza Petrolera vs Deportivo Cali
#      Liga: Colombia_1 Liga BetPlay | Faltam: 595 min
#      Prob=40.0% | Odd=2.93 | EV=+17.2%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Casa      | MVV vs Willem II
#      Liga: Holanda_2 Eerste Divisie | Faltam: 280 min
#      Prob=26.6% | Odd=4.4 | EV=+17.1%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Over 2.5       | Panaitolikos vs Panserraikos
#      Liga: Grecia_1 Super League | Faltam: 355 min
#      Prob=53.1% | Odd=2.2 | EV=+16.9%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ BTTS           | Asteras Tripolis vs Panathinaikos
#      Liga: Grecia_1 Super League | Faltam: 355 min
#      Prob=54.3% | Odd=2.15 | EV=+16.8%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Fora      | Roma vs Lecce
#      Liga: Italia_1 Serie A | Faltam: 355 min
#      Prob=15.5% | Odd=7.5 | EV=+16.5%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Casa      | RSC Anderlecht vs Cercle Brugge
#      Liga: Belgica_1 Pro League | Faltam: 385 min
#      Prob=56.5% | Odd=2.06 | EV=+16.4%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Casa      | Slaven Koprivnica vs Osijek
#      Liga: Croacia_1 HNL | Faltam: 175 min
#      Prob=54.0% | Odd=2.15 | EV=+16.0%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Fora      | América de Cali vs Llaneros
#      Liga: Colombia_1 Liga BetPlay | Faltam: 5155 min
#      Prob=23.2% | Odd=5 | EV=+15.9%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Casa      | Vitória vs Mirassol
#      Liga: Brasileiro_A Serie A | Faltam: 625 min
#      Prob=44.5% | Odd=2.6 | EV=+15.8%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Fora      | Santa Fe vs Independiente Medellín
#      Liga: Colombia_1 Liga BetPlay | Faltam: 2045 min
#      Prob=34.4% | Odd=3.35 | EV=+15.4%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Over 2.5       | Paris vs Le Havre
#      Liga: Franca_1 Ligue 1 | Faltam: 310 min
#      Prob=53.6% | Odd=2.15 | EV=+15.3%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Fora      | Deportivo Riestra vs San Lorenzo
#      Liga: Argentina_1 Liga Profesional | Faltam: 4975 min
#      Prob=33.9% | Odd=3.4 | EV=+15.3%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Casa      | Dundee United vs Celtic
#      Liga: Escocia_1 Premiership | Faltam: 85 min
#      Prob=21.5% | Odd=5.35 | EV=+15.3%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Over 2.5       | Bologna vs Lazio
#      Liga: Italia_1 Serie A | Faltam: 175 min
#      Prob=52.3% | Odd=2.2 | EV=+15.1%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Fora      | Olympique Marseille vs Lille
#      Liga: Franca_1 Ligue 1 | Faltam: 310 min
#      Prob=30.2% | Odd=3.8 | EV=+14.6%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Casa      | Estudiantes Río Cuarto vs River Plate
#      Liga: Argentina_1 Liga Profesional | Faltam: 580 min
#      Prob=16.9% | Odd=6.77 | EV=+14.6%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ BTTS           | América de Cali vs Llaneros
#      Liga: Colombia_1 Liga BetPlay | Faltam: 5155 min
#      Prob=53.3% | Odd=2.15 | EV=+14.5%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Over 2.5       | Slaven Koprivnica vs Osijek
#      Liga: Croacia_1 HNL | Faltam: 175 min
#      Prob=53.0% | Odd=2.15 | EV=+14.1%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ BTTS           | Burgos CF vs Córdoba
#      Liga: Espanha_2 Segunda Division | Faltam: 115 min
#      Prob=58.5% | Odd=1.95 | EV=+14.0%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Over 2.5       | Estudiantes Río Cuarto vs River Plate
#      Liga: Argentina_1 Liga Profesional | Faltam: 580 min
#      Prob=48.5% | Odd=2.35 | EV=+13.9%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Over 2.5       | Junior vs Atlético Bucaramanga
#      Liga: Colombia_1 Liga BetPlay | Faltam: 3595 min
#      Prob=50.6% | Odd=2.25 | EV=+13.9%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ BTTS           | Botev Vratsa vs Lokomotiv Plovdiv
#      Liga: Bulgaria_1 First League | Faltam: 265 min
#      Prob=55.3% | Odd=2.05 | EV=+13.4%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ BTTS           | Roma vs Lecce
#      Liga: Italia_1 Serie A | Faltam: 355 min
#      Prob=53.9% | Odd=2.1 | EV=+13.2%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Over 2.5       | Sporting Braga vs Porto
#      Liga: Portugal_1 Primeira Liga | Faltam: 565 min
#      Prob=50.1% | Odd=2.25 | EV=+12.7%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Fora      | Aris vs OFI
#      Liga: Grecia_1 Super League | Faltam: 355 min
#      Prob=18.7% | Odd=6.03 | EV=+12.5%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Over 2.5       | UD Las Palmas vs Sporting Gijón
#      Liga: Espanha_2 Segunda Division | Faltam: 385 min
#      Prob=53.5% | Odd=2.1 | EV=+12.4%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Over 2.5       | Aris vs OFI
#      Liga: Grecia_1 Super League | Faltam: 355 min
#      Prob=53.5% | Odd=2.1 | EV=+12.4%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Over 2.5       | América de Cali vs Llaneros
#      Liga: Colombia_1 Liga BetPlay | Faltam: 5155 min
#      Prob=52.4% | Odd=2.14 | EV=+12.1%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Over 2.5       | Asteras Tripolis vs Panathinaikos
#      Liga: Grecia_1 Super League | Faltam: 355 min
#      Prob=47.7% | Odd=2.35 | EV=+12.0%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ BTTS           | Panaitolikos vs Panserraikos
#      Liga: Grecia_1 Super League | Faltam: 355 min
#      Prob=54.6% | Odd=2.05 | EV=+12.0%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Fora      | Asteras Tripolis vs Panathinaikos
#      Liga: Grecia_1 Super League | Faltam: 355 min
#      Prob=65.2% | Odd=1.7 | EV=+10.9%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Fora      | Emmen vs Cambuur
#      Liga: Holanda_2 Eerste Divisie | Faltam: 3355 min
#      Prob=59.9% | Odd=1.85 | EV=+10.9%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Casa      | Real Madrid vs Atlético Madrid
#      Liga: Espanha_1 La Liga | Faltam: 535 min
#      Prob=58.8% | Odd=1.88 | EV=+10.6%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Over 2.5       | Vitória vs Mirassol
#      Liga: Brasileiro_A Serie A | Faltam: 625 min
#      Prob=50.1% | Odd=2.2 | EV=+10.2%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Fora      | Newcastle United vs Sunderland
#      Liga: Inglaterra_1 Premier League | Faltam: 55 min
#      Prob=22.0% | Odd=5 | EV=+10.1%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Fora      | Sporting Braga vs Porto
#      Liga: Portugal_1 Primeira Liga | Faltam: 565 min
#      Prob=50.0% | Odd=2.2 | EV=+10.0%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ BTTS           | Independiente Rivadavia vs Rosario Central
#      Liga: Argentina_1 Liga Profesional | Faltam: 850 min
#      Prob=54.2% | Odd=2.03 | EV=+10.0%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Fora      | Augsburg vs Stuttgart
#      Liga: Alemanha_1 Bundesliga | Faltam: 445 min
#      Prob=53.4% | Odd=2.05 | EV=+9.5%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Over 2.5       | Roma vs Lecce
#      Liga: Italia_1 Serie A | Faltam: 355 min
#      Prob=55.7% | Odd=1.95 | EV=+8.6%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ BTTS           | Corinthians vs Flamengo
#      Liga: Brasileiro_A Serie A | Faltam: 745 min
#      Prob=55.6% | Odd=1.95 | EV=+8.5%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ BTTS           | Aris vs OFI
#      Liga: Grecia_1 Super League | Faltam: 355 min
#      Prob=54.0% | Odd=2 | EV=+8.0%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Over 2.5       | Gorica vs Rijeka
#      Liga: Croacia_1 HNL | Faltam: 340 min
#      Prob=50.2% | Odd=2.15 | EV=+7.9%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Fora      | Burgos CF vs Córdoba
#      Liga: Espanha_2 Segunda Division | Faltam: 115 min
#      Prob=32.1% | Odd=3.36 | EV=+7.7%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Fora      | CSKA Sofia vs Dobrudzha 1919
#      Liga: Bulgaria_1 First League | Faltam: 115 min
#      Prob=8.6% | Odd=12.5 | EV=+7.1%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Fora      | St. Pauli vs Freiburg
#      Liga: Alemanha_1 Bundesliga | Faltam: 325 min
#      Prob=37.8% | Odd=2.83 | EV=+7.0%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Casa      | Bologna vs Lazio
#      Liga: Italia_1 Serie A | Faltam: 175 min
#      Prob=45.0% | Odd=2.37 | EV=+6.6%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ BTTS           | Fortaleza CEIF vs Deportivo Pasto
#      Liga: Colombia_1 Liga BetPlay | Faltam: 3715 min
#      Prob=54.1% | Odd=1.97 | EV=+6.5%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ BTTS           | Jaguares de Córdoba vs Rionegro Águilas
#      Liga: Colombia_1 Liga BetPlay | Faltam: 2175 min
#      Prob=53.7% | Odd=1.98 | EV=+6.4%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Over 2.5       | Mirandés vs Real Valladolid
#      Liga: Espanha_2 Segunda Division | Faltam: 250 min
#      Prob=50.6% | Odd=2.1 | EV=+6.3%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ BTTS           | UD Las Palmas vs Sporting Gijón
#      Liga: Espanha_2 Segunda Division | Faltam: 385 min
#      Prob=55.3% | Odd=1.92 | EV=+6.2%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ BTTS           | St. Pauli vs Freiburg
#      Liga: Alemanha_1 Bundesliga | Faltam: 325 min
#      Prob=55.5% | Odd=1.91 | EV=+6.0%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Fora      | Empoli vs Pescara
#      Liga: Italia_2 Serie B | Faltam: 175 min
#      Prob=30.6% | Odd=3.45 | EV=+5.7%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Casa      | Levadiakos vs Atromitos
#      Liga: Grecia_1 Super League | Faltam: 355 min
#      Prob=50.1% | Odd=2.1 | EV=+5.2%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Over 2.5       | Jaguares de Córdoba vs Rionegro Águilas
#      Liga: Colombia_1 Liga BetPlay | Faltam: 2175 min
#      Prob=48.9% | Odd=2.15 | EV=+5.1%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Casa      | Preußen Münster vs Magdeburg
#      Liga: Alemanha_2 2. Bundesliga | Faltam: 85 min
#      Prob=35.4% | Odd=2.95 | EV=+4.5%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ BTTS           | Alianza Petrolera vs Deportivo Cali
#      Liga: Colombia_1 Liga BetPlay | Faltam: 595 min
#      Prob=53.6% | Odd=1.95 | EV=+4.5%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Fora      | CD Castellón vs Cultural y Deportiva Leonesa
#      Liga: Espanha_2 Segunda Division | Faltam: 1945 min
#      Prob=14.7% | Odd=7.1 | EV=+4.3%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ BTTS           | Sporting Braga vs Porto
#      Liga: Portugal_1 Primeira Liga | Faltam: 565 min
#      Prob=53.4% | Odd=1.95 | EV=+4.2%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Over 2.5       | Nantes vs Strasbourg
#      Liga: Franca_1 Ligue 1 | Faltam: 520 min
#      Prob=50.3% | Odd=2.06 | EV=+3.7%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Over 2.5       | Newcastle United vs Sunderland
#      Liga: Inglaterra_1 Premier League | Faltam: 55 min
#      Prob=54.4% | Odd=1.9 | EV=+3.3%
#      Movimento odd: ➡️ +0.0%
#
# [08:04:37] ✅ CSV atualizado → rodada_atual_v3.csv
#
# ── Ciclo 1 ──────────────────────────────
# [08:36:00] 🔄 Atualizando 93 jogos...
#
# 🚨🚨🚨 ALERTAS DE VALOR 🚨🚨🚨
#   ✅ Back Fora      | AEK Athens vs Kifisia
#      Liga: Grecia_1 Super League | Faltam: 324 min
#      Prob=11.1% | Odd=20 | EV=+122.7%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Over 2.5       | Deportivo Riestra vs San Lorenzo
#      Liga: Argentina_1 Liga Profesional | Faltam: 4944 min
#      Prob=50.9% | Odd=4 | EV=+103.6%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Fora      | Huracán vs Barracas Central
#      Liga: Argentina_1 Liga Profesional | Faltam: 2199 min
#      Prob=33.9% | Odd=5.5 | EV=+86.4%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Casa      | Volos NFC vs PAOK
#      Liga: Grecia_1 Super League | Faltam: 324 min
#      Prob=14.5% | Odd=12 | EV=+73.9%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Fora      | Estudiantes vs Central Córdoba SdE
#      Liga: Argentina_1 Liga Profesional | Faltam: 2064 min
#      Prob=22.2% | Odd=7.2 | EV=+60.2%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Fora      | Club Brugge vs KV Mechelen
#      Liga: Belgica_1 Pro League | Faltam: 354 min
#      Prob=15.0% | Odd=10.5 | EV=+57.5%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Fora      | Boca Juniors vs Instituto
#      Liga: Argentina_1 Liga Profesional | Faltam: 684 min
#      Prob=29.6% | Odd=5.25 | EV=+55.4%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Over 2.5       | Sarmiento vs Aldosivi
#      Liga: Argentina_1 Liga Profesional | Faltam: 414 min
#      Prob=51.4% | Odd=3 | EV=+54.3%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Over 2.5       | Huracán vs Barracas Central
#      Liga: Argentina_1 Liga Profesional | Faltam: 2199 min
#      Prob=51.3% | Odd=3 | EV=+54.0%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Fora      | Cruzeiro vs Santos
#      Liga: Brasileiro_A Serie A | Faltam: 444 min
#      Prob=30.2% | Odd=4.82 | EV=+45.4%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ BTTS           | Huracán vs Barracas Central
#      Liga: Argentina_1 Liga Profesional | Faltam: 2199 min
#      Prob=54.0% | Odd=2.61 | EV=+41.0%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ BTTS           | Deportivo Riestra vs San Lorenzo
#      Liga: Argentina_1 Liga Profesional | Faltam: 4944 min
#      Prob=53.6% | Odd=2.6 | EV=+39.5%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Over 2.5       | Argentinos Juniors vs Platense
#      Liga: Argentina_1 Liga Profesional | Faltam: 819 min
#      Prob=52.7% | Odd=2.61 | EV=+37.6%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Fora      | Atlético PR vs Coritiba
#      Liga: Brasileiro_A Serie A | Faltam: 444 min
#      Prob=31.7% | Odd=4.32 | EV=+36.9%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Fora      | Fortaleza CEIF vs Deportivo Pasto
#      Liga: Colombia_1 Liga BetPlay | Faltam: 3684 min
#      Prob=42.8% | Odd=3.2 | EV=+36.8%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Fora      | Junior vs Atlético Bucaramanga
#      Liga: Colombia_1 Liga BetPlay | Faltam: 3564 min
#      Prob=36.8% | Odd=3.65 | EV=+34.1%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ BTTS           | Olympiakos Piraeus vs Larissa
#      Liga: Grecia_1 Super League | Faltam: 324 min
#      Prob=54.0% | Odd=2.45 | EV=+32.3%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Casa      | Bochum vs Holstein Kiel
#      Liga: Alemanha_2 2. Bundesliga | Faltam: 54 min
#      Prob=64.9% | Odd=2.03 | EV=+31.7%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Fora      | Como vs Pisa
#      Liga: Italia_1 Serie A | Faltam: -6 min
#      Prob=9.9% | Odd=13.28 | EV=+31.3%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Over 2.5       | Boca Juniors vs Instituto
#      Liga: Argentina_1 Liga Profesional | Faltam: 684 min
#      Prob=50.5% | Odd=2.6 | EV=+31.2%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Over 2.5       | Estudiantes vs Central Córdoba SdE
#      Liga: Argentina_1 Liga Profesional | Faltam: 2064 min
#      Prob=52.4% | Odd=2.5 | EV=+30.9%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ BTTS           | Estudiantes vs Central Córdoba SdE
#      Liga: Argentina_1 Liga Profesional | Faltam: 2064 min
#      Prob=53.0% | Odd=2.45 | EV=+29.8%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Fora      | Jaguares de Córdoba vs Rionegro Águilas
#      Liga: Colombia_1 Liga BetPlay | Faltam: 2144 min
#      Prob=49.4% | Odd=2.62 | EV=+29.3%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ BTTS           | Sarmiento vs Aldosivi
#      Liga: Argentina_1 Liga Profesional | Faltam: 414 min
#      Prob=53.9% | Odd=2.4 | EV=+29.3%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ BTTS           | Argentinos Juniors vs Platense
#      Liga: Argentina_1 Liga Profesional | Faltam: 819 min
#      Prob=52.6% | Odd=2.45 | EV=+28.9%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ BTTS           | AEK Athens vs Kifisia
#      Liga: Grecia_1 Super League | Faltam: 324 min
#      Prob=55.9% | Odd=2.3 | EV=+28.7%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Over 2.5       | Fortaleza CEIF vs Deportivo Pasto
#      Liga: Colombia_1 Liga BetPlay | Faltam: 3684 min
#      Prob=50.8% | Odd=2.5 | EV=+27.1%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Casa      | Várda SE vs Ferencváros
#      Liga: Hungria_1 NB I | Faltam: 399 min
#      Prob=23.5% | Odd=5.4 | EV=+26.7%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Over 2.5       | Boyacá Chicó vs Deportes Tolima
#      Liga: Colombia_1 Liga BetPlay | Faltam: 1884 min
#      Prob=49.9% | Odd=2.5 | EV=+24.7%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Over 2.5       | Independiente Rivadavia vs Rosario Central
#      Liga: Argentina_1 Liga Profesional | Faltam: 819 min
#      Prob=52.1% | Odd=2.38 | EV=+24.0%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ BTTS           | Boca Juniors vs Instituto
#      Liga: Argentina_1 Liga Profesional | Faltam: 684 min
#      Prob=53.8% | Odd=2.3 | EV=+23.8%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Fora      | Sarmiento vs Aldosivi
#      Liga: Argentina_1 Liga Profesional | Faltam: 414 min
#      Prob=32.5% | Odd=3.8 | EV=+23.3%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Over 2.5       | Levadiakos vs Atromitos
#      Liga: Grecia_1 Super League | Faltam: 324 min
#      Prob=56.1% | Odd=2.19 | EV=+22.9%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Over 2.5       | Atlético PR vs Coritiba
#      Liga: Brasileiro_A Serie A | Faltam: 444 min
#      Prob=55.9% | Odd=2.2 | EV=+22.9%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Fora      | Fortuna Düsseldorf vs Hertha BSC
#      Liga: Alemanha_2 2. Bundesliga | Faltam: 54 min
#      Prob=40.6% | Odd=3 | EV=+21.8%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Fora      | Athletic Club Bilbao vs Real Betis
#      Liga: Espanha_1 La Liga | Faltam: 354 min
#      Prob=35.3% | Odd=3.45 | EV=+21.8%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ BTTS           | Boyacá Chicó vs Deportes Tolima
#      Liga: Colombia_1 Liga BetPlay | Faltam: 1884 min
#      Prob=54.7% | Odd=2.22 | EV=+21.5%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Over 2.5       | Botev Vratsa vs Lokomotiv Plovdiv
#      Liga: Bulgaria_1 First League | Faltam: 234 min
#      Prob=51.6% | Odd=2.35 | EV=+21.4%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ BTTS           | CSKA Sofia vs Dobrudzha 1919
#      Liga: Bulgaria_1 First League | Faltam: 84 min
#      Prob=52.8% | Odd=2.3 | EV=+21.3%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Over 2.5       | Burgos CF vs Córdoba
#      Liga: Espanha_2 Segunda Division | Faltam: 84 min
#      Prob=53.7% | Odd=2.25 | EV=+20.9%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Casa      | Sint-Truiden vs Union Saint-Gilloise
#      Liga: Belgica_1 Pro League | Faltam: 354 min
#      Prob=35.0% | Odd=3.45 | EV=+20.8%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ BTTS           | Volos NFC vs PAOK
#      Liga: Grecia_1 Super League | Faltam: 324 min
#      Prob=52.5% | Odd=2.3 | EV=+20.8%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Casa      | Remo vs Bahia
#      Liga: Brasileiro_A Serie A | Faltam: 444 min
#      Prob=34.3% | Odd=3.5 | EV=+19.9%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Over 2.5       | Corinthians vs Flamengo
#      Liga: Brasileiro_A Serie A | Faltam: 714 min
#      Prob=53.3% | Odd=2.25 | EV=+19.9%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Over 2.5       | St. Pauli vs Freiburg
#      Liga: Alemanha_1 Bundesliga | Faltam: 294 min
#      Prob=52.0% | Odd=2.3 | EV=+19.6%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Fora      | Argentinos Juniors vs Platense
#      Liga: Argentina_1 Liga Profesional | Faltam: 819 min
#      Prob=22.6% | Odd=5.3 | EV=+19.6%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Fora      | Internacional vs Chapecoense
#      Liga: Brasileiro_A Serie A | Faltam: 594 min
#      Prob=18.4% | Odd=6.5 | EV=+19.5%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Over 2.5       | Deportivo Pereira vs Cúcuta Deportivo
#      Liga: Colombia_1 Liga BetPlay | Faltam: 3414 min
#      Prob=51.3% | Odd=2.33 | EV=+19.5%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ BTTS           | Como vs Pisa
#      Liga: Italia_1 Serie A | Faltam: -6 min
#      Prob=54.1% | Odd=2.2 | EV=+19.0%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ BTTS           | Estudiantes Río Cuarto vs River Plate
#      Liga: Argentina_1 Liga Profesional | Faltam: 549 min
#      Prob=55.3% | Odd=2.15 | EV=+18.9%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Fora      | Puskás vs Debrecen
#      Liga: Hungria_1 NB I | Faltam: 114 min
#      Prob=36.9% | Odd=3.2 | EV=+18.0%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Over 2.5       | Alianza Petrolera vs Deportivo Cali
#      Liga: Colombia_1 Liga BetPlay | Faltam: 564 min
#      Prob=50.2% | Odd=2.35 | EV=+18.0%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Casa      | Corinthians vs Flamengo
#      Liga: Brasileiro_A Serie A | Faltam: 714 min
#      Prob=37.3% | Odd=3.15 | EV=+17.6%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ BTTS           | Alverca vs Sporting CP
#      Liga: Portugal_1 Primeira Liga | Faltam: 384 min
#      Prob=55.2% | Odd=2.13 | EV=+17.5%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Fora      | Alianza Petrolera vs Deportivo Cali
#      Liga: Colombia_1 Liga BetPlay | Faltam: 564 min
#      Prob=40.0% | Odd=2.93 | EV=+17.2%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Casa      | MVV vs Willem II
#      Liga: Holanda_2 Eerste Divisie | Faltam: 249 min
#      Prob=26.6% | Odd=4.4 | EV=+17.1%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Over 2.5       | Panaitolikos vs Panserraikos
#      Liga: Grecia_1 Super League | Faltam: 324 min
#      Prob=53.1% | Odd=2.2 | EV=+16.9%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ BTTS           | Asteras Tripolis vs Panathinaikos
#      Liga: Grecia_1 Super League | Faltam: 324 min
#      Prob=54.3% | Odd=2.15 | EV=+16.8%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Fora      | Roma vs Lecce
#      Liga: Italia_1 Serie A | Faltam: 324 min
#      Prob=15.5% | Odd=7.5 | EV=+16.5%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Casa      | RSC Anderlecht vs Cercle Brugge
#      Liga: Belgica_1 Pro League | Faltam: 354 min
#      Prob=56.5% | Odd=2.06 | EV=+16.4%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Casa      | Slaven Koprivnica vs Osijek
#      Liga: Croacia_1 HNL | Faltam: 144 min
#      Prob=54.0% | Odd=2.15 | EV=+16.0%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Fora      | América de Cali vs Llaneros
#      Liga: Colombia_1 Liga BetPlay | Faltam: 5124 min
#      Prob=23.2% | Odd=5 | EV=+15.9%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Casa      | Vitória vs Mirassol
#      Liga: Brasileiro_A Serie A | Faltam: 594 min
#      Prob=44.5% | Odd=2.6 | EV=+15.8%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Fora      | Santa Fe vs Independiente Medellín
#      Liga: Colombia_1 Liga BetPlay | Faltam: 2014 min
#      Prob=34.4% | Odd=3.35 | EV=+15.4%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Over 2.5       | Paris vs Le Havre
#      Liga: Franca_1 Ligue 1 | Faltam: 279 min
#      Prob=53.6% | Odd=2.15 | EV=+15.3%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Fora      | Deportivo Riestra vs San Lorenzo
#      Liga: Argentina_1 Liga Profesional | Faltam: 4944 min
#      Prob=33.9% | Odd=3.4 | EV=+15.3%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Casa      | Dundee United vs Celtic
#      Liga: Escocia_1 Premiership | Faltam: 54 min
#      Prob=21.5% | Odd=5.35 | EV=+15.3%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Over 2.5       | Bologna vs Lazio
#      Liga: Italia_1 Serie A | Faltam: 144 min
#      Prob=52.3% | Odd=2.2 | EV=+15.1%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Fora      | Olympique Marseille vs Lille
#      Liga: Franca_1 Ligue 1 | Faltam: 279 min
#      Prob=30.2% | Odd=3.8 | EV=+14.6%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Casa      | Estudiantes Río Cuarto vs River Plate
#      Liga: Argentina_1 Liga Profesional | Faltam: 549 min
#      Prob=16.9% | Odd=6.77 | EV=+14.6%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ BTTS           | América de Cali vs Llaneros
#      Liga: Colombia_1 Liga BetPlay | Faltam: 5124 min
#      Prob=53.3% | Odd=2.15 | EV=+14.5%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Over 2.5       | Slaven Koprivnica vs Osijek
#      Liga: Croacia_1 HNL | Faltam: 144 min
#      Prob=53.0% | Odd=2.15 | EV=+14.1%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ BTTS           | Burgos CF vs Córdoba
#      Liga: Espanha_2 Segunda Division | Faltam: 84 min
#      Prob=58.5% | Odd=1.95 | EV=+14.0%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Over 2.5       | Estudiantes Río Cuarto vs River Plate
#      Liga: Argentina_1 Liga Profesional | Faltam: 549 min
#      Prob=48.5% | Odd=2.35 | EV=+13.9%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Over 2.5       | Junior vs Atlético Bucaramanga
#      Liga: Colombia_1 Liga BetPlay | Faltam: 3564 min
#      Prob=50.6% | Odd=2.25 | EV=+13.9%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ BTTS           | Botev Vratsa vs Lokomotiv Plovdiv
#      Liga: Bulgaria_1 First League | Faltam: 234 min
#      Prob=55.3% | Odd=2.05 | EV=+13.4%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ BTTS           | Roma vs Lecce
#      Liga: Italia_1 Serie A | Faltam: 324 min
#      Prob=53.9% | Odd=2.1 | EV=+13.2%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Over 2.5       | Sporting Braga vs Porto
#      Liga: Portugal_1 Primeira Liga | Faltam: 534 min
#      Prob=50.1% | Odd=2.25 | EV=+12.7%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Fora      | Aris vs OFI
#      Liga: Grecia_1 Super League | Faltam: 324 min
#      Prob=18.7% | Odd=6.03 | EV=+12.5%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Over 2.5       | UD Las Palmas vs Sporting Gijón
#      Liga: Espanha_2 Segunda Division | Faltam: 354 min
#      Prob=53.5% | Odd=2.1 | EV=+12.4%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Over 2.5       | Aris vs OFI
#      Liga: Grecia_1 Super League | Faltam: 324 min
#      Prob=53.5% | Odd=2.1 | EV=+12.4%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Over 2.5       | América de Cali vs Llaneros
#      Liga: Colombia_1 Liga BetPlay | Faltam: 5124 min
#      Prob=52.4% | Odd=2.14 | EV=+12.1%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Over 2.5       | Asteras Tripolis vs Panathinaikos
#      Liga: Grecia_1 Super League | Faltam: 324 min
#      Prob=47.7% | Odd=2.35 | EV=+12.0%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ BTTS           | Panaitolikos vs Panserraikos
#      Liga: Grecia_1 Super League | Faltam: 324 min
#      Prob=54.6% | Odd=2.05 | EV=+12.0%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Fora      | Asteras Tripolis vs Panathinaikos
#      Liga: Grecia_1 Super League | Faltam: 324 min
#      Prob=65.2% | Odd=1.7 | EV=+10.9%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Fora      | Emmen vs Cambuur
#      Liga: Holanda_2 Eerste Divisie | Faltam: 3324 min
#      Prob=59.9% | Odd=1.85 | EV=+10.9%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Casa      | Real Madrid vs Atlético Madrid
#      Liga: Espanha_1 La Liga | Faltam: 504 min
#      Prob=58.8% | Odd=1.88 | EV=+10.6%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Over 2.5       | Vitória vs Mirassol
#      Liga: Brasileiro_A Serie A | Faltam: 594 min
#      Prob=50.1% | Odd=2.2 | EV=+10.2%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Fora      | Newcastle United vs Sunderland
#      Liga: Inglaterra_1 Premier League | Faltam: 24 min
#      Prob=22.0% | Odd=5 | EV=+10.1%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Fora      | Sporting Braga vs Porto
#      Liga: Portugal_1 Primeira Liga | Faltam: 534 min
#      Prob=50.0% | Odd=2.2 | EV=+10.0%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ BTTS           | Independiente Rivadavia vs Rosario Central
#      Liga: Argentina_1 Liga Profesional | Faltam: 819 min
#      Prob=54.2% | Odd=2.03 | EV=+10.0%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Fora      | Augsburg vs Stuttgart
#      Liga: Alemanha_1 Bundesliga | Faltam: 414 min
#      Prob=53.4% | Odd=2.05 | EV=+9.5%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Over 2.5       | Roma vs Lecce
#      Liga: Italia_1 Serie A | Faltam: 324 min
#      Prob=55.7% | Odd=1.95 | EV=+8.6%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ BTTS           | Corinthians vs Flamengo
#      Liga: Brasileiro_A Serie A | Faltam: 714 min
#      Prob=55.6% | Odd=1.95 | EV=+8.5%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ BTTS           | Aris vs OFI
#      Liga: Grecia_1 Super League | Faltam: 324 min
#      Prob=54.0% | Odd=2 | EV=+8.0%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Over 2.5       | Gorica vs Rijeka
#      Liga: Croacia_1 HNL | Faltam: 309 min
#      Prob=50.2% | Odd=2.15 | EV=+7.9%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Fora      | Standard Liège vs KVC Westerlo
#      Liga: Belgica_1 Pro League | Faltam: 354 min
#      Prob=36.0% | Odd=2.99 | EV=+7.8%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Fora      | Burgos CF vs Córdoba
#      Liga: Espanha_2 Segunda Division | Faltam: 84 min
#      Prob=32.1% | Odd=3.36 | EV=+7.7%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Fora      | CSKA Sofia vs Dobrudzha 1919
#      Liga: Bulgaria_1 First League | Faltam: 84 min
#      Prob=8.6% | Odd=12.5 | EV=+7.1%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Fora      | St. Pauli vs Freiburg
#      Liga: Alemanha_1 Bundesliga | Faltam: 294 min
#      Prob=37.8% | Odd=2.83 | EV=+7.0%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Casa      | Bologna vs Lazio
#      Liga: Italia_1 Serie A | Faltam: 144 min
#      Prob=45.0% | Odd=2.37 | EV=+6.6%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ BTTS           | Fortaleza CEIF vs Deportivo Pasto
#      Liga: Colombia_1 Liga BetPlay | Faltam: 3684 min
#      Prob=54.1% | Odd=1.97 | EV=+6.5%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ BTTS           | Jaguares de Córdoba vs Rionegro Águilas
#      Liga: Colombia_1 Liga BetPlay | Faltam: 2144 min
#      Prob=53.7% | Odd=1.98 | EV=+6.4%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Over 2.5       | Mirandés vs Real Valladolid
#      Liga: Espanha_2 Segunda Division | Faltam: 219 min
#      Prob=50.6% | Odd=2.1 | EV=+6.3%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ BTTS           | UD Las Palmas vs Sporting Gijón
#      Liga: Espanha_2 Segunda Division | Faltam: 354 min
#      Prob=55.3% | Odd=1.92 | EV=+6.2%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Over 2.5       | Standard Liège vs KVC Westerlo
#      Liga: Belgica_1 Pro League | Faltam: 354 min
#      Prob=51.5% | Odd=2.06 | EV=+6.1%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ BTTS           | St. Pauli vs Freiburg
#      Liga: Alemanha_1 Bundesliga | Faltam: 294 min
#      Prob=55.5% | Odd=1.91 | EV=+6.0%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Fora      | Empoli vs Pescara
#      Liga: Italia_2 Serie B | Faltam: 144 min
#      Prob=30.6% | Odd=3.45 | EV=+5.7%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Casa      | Levadiakos vs Atromitos
#      Liga: Grecia_1 Super League | Faltam: 324 min
#      Prob=50.1% | Odd=2.1 | EV=+5.2%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Over 2.5       | Jaguares de Córdoba vs Rionegro Águilas
#      Liga: Colombia_1 Liga BetPlay | Faltam: 2144 min
#      Prob=48.9% | Odd=2.15 | EV=+5.1%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Casa      | Preußen Münster vs Magdeburg
#      Liga: Alemanha_2 2. Bundesliga | Faltam: 54 min
#      Prob=35.4% | Odd=2.95 | EV=+4.5%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ BTTS           | Alianza Petrolera vs Deportivo Cali
#      Liga: Colombia_1 Liga BetPlay | Faltam: 564 min
#      Prob=53.6% | Odd=1.95 | EV=+4.5%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Fora      | CD Castellón vs Cultural y Deportiva Leonesa
#      Liga: Espanha_2 Segunda Division | Faltam: 1914 min
#      Prob=14.7% | Odd=7.1 | EV=+4.3%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ BTTS           | Sporting Braga vs Porto
#      Liga: Portugal_1 Primeira Liga | Faltam: 534 min
#      Prob=53.4% | Odd=1.95 | EV=+4.2%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Over 2.5       | Nantes vs Strasbourg
#      Liga: Franca_1 Ligue 1 | Faltam: 489 min
#      Prob=50.3% | Odd=2.06 | EV=+3.7%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Over 2.5       | Newcastle United vs Sunderland
#      Liga: Inglaterra_1 Premier League | Faltam: 24 min
#      Prob=54.4% | Odd=1.9 | EV=+3.3%
#      Movimento odd: ➡️ +0.0%
#
# [08:36:00] ✅ CSV atualizado → rodada_atual_v3.csv
#
# ── Ciclo 2 ──────────────────────────────
# [09:07:23] 🔄 Atualizando 90 jogos...
#
# 🚨🚨🚨 ALERTAS DE VALOR 🚨🚨🚨
#   ✅ Back Fora      | AEK Athens vs Kifisia
#      Liga: Grecia_1 Super League | Faltam: 292 min
#      Prob=11.1% | Odd=20 | EV=+122.7%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Over 2.5       | Deportivo Riestra vs San Lorenzo
#      Liga: Argentina_1 Liga Profesional | Faltam: 4912 min
#      Prob=50.9% | Odd=4 | EV=+103.6%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Fora      | Huracán vs Barracas Central
#      Liga: Argentina_1 Liga Profesional | Faltam: 2167 min
#      Prob=33.9% | Odd=5.5 | EV=+86.4%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Casa      | Volos NFC vs PAOK
#      Liga: Grecia_1 Super League | Faltam: 292 min
#      Prob=14.5% | Odd=12 | EV=+73.9%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Fora      | Estudiantes vs Central Córdoba SdE
#      Liga: Argentina_1 Liga Profesional | Faltam: 2032 min
#      Prob=22.2% | Odd=7.2 | EV=+60.2%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Fora      | Club Brugge vs KV Mechelen
#      Liga: Belgica_1 Pro League | Faltam: 322 min
#      Prob=15.0% | Odd=10.5 | EV=+57.5%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Fora      | Boca Juniors vs Instituto
#      Liga: Argentina_1 Liga Profesional | Faltam: 652 min
#      Prob=29.6% | Odd=5.25 | EV=+55.4%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Over 2.5       | Sarmiento vs Aldosivi
#      Liga: Argentina_1 Liga Profesional | Faltam: 382 min
#      Prob=51.4% | Odd=3 | EV=+54.3%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Over 2.5       | Huracán vs Barracas Central
#      Liga: Argentina_1 Liga Profesional | Faltam: 2167 min
#      Prob=51.3% | Odd=3 | EV=+54.0%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Fora      | Cruzeiro vs Santos
#      Liga: Brasileiro_A Serie A | Faltam: 412 min
#      Prob=30.2% | Odd=4.82 | EV=+45.4%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ BTTS           | Huracán vs Barracas Central
#      Liga: Argentina_1 Liga Profesional | Faltam: 2167 min
#      Prob=54.0% | Odd=2.61 | EV=+41.0%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ BTTS           | Deportivo Riestra vs San Lorenzo
#      Liga: Argentina_1 Liga Profesional | Faltam: 4912 min
#      Prob=53.6% | Odd=2.6 | EV=+39.5%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Over 2.5       | Argentinos Juniors vs Platense
#      Liga: Argentina_1 Liga Profesional | Faltam: 787 min
#      Prob=52.7% | Odd=2.61 | EV=+37.6%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Fora      | Atlético PR vs Coritiba
#      Liga: Brasileiro_A Serie A | Faltam: 412 min
#      Prob=31.7% | Odd=4.32 | EV=+36.9%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Fora      | Fortaleza CEIF vs Deportivo Pasto
#      Liga: Colombia_1 Liga BetPlay | Faltam: 3652 min
#      Prob=42.8% | Odd=3.2 | EV=+36.8%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Fora      | Junior vs Atlético Bucaramanga
#      Liga: Colombia_1 Liga BetPlay | Faltam: 3532 min
#      Prob=36.8% | Odd=3.65 | EV=+34.1%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ BTTS           | Olympiakos Piraeus vs Larissa
#      Liga: Grecia_1 Super League | Faltam: 292 min
#      Prob=54.0% | Odd=2.45 | EV=+32.3%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Casa      | Bochum vs Holstein Kiel
#      Liga: Alemanha_2 2. Bundesliga | Faltam: 22 min
#      Prob=64.9% | Odd=2.03 | EV=+31.7%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Over 2.5       | Boca Juniors vs Instituto
#      Liga: Argentina_1 Liga Profesional | Faltam: 652 min
#      Prob=50.5% | Odd=2.6 | EV=+31.2%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Over 2.5       | Estudiantes vs Central Córdoba SdE
#      Liga: Argentina_1 Liga Profesional | Faltam: 2032 min
#      Prob=52.4% | Odd=2.5 | EV=+30.9%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ BTTS           | Estudiantes vs Central Córdoba SdE
#      Liga: Argentina_1 Liga Profesional | Faltam: 2032 min
#      Prob=53.0% | Odd=2.45 | EV=+29.8%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Fora      | Jaguares de Córdoba vs Rionegro Águilas
#      Liga: Colombia_1 Liga BetPlay | Faltam: 2112 min
#      Prob=49.4% | Odd=2.62 | EV=+29.3%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ BTTS           | Sarmiento vs Aldosivi
#      Liga: Argentina_1 Liga Profesional | Faltam: 382 min
#      Prob=53.9% | Odd=2.4 | EV=+29.3%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ BTTS           | Argentinos Juniors vs Platense
#      Liga: Argentina_1 Liga Profesional | Faltam: 787 min
#      Prob=52.6% | Odd=2.45 | EV=+28.9%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ BTTS           | AEK Athens vs Kifisia
#      Liga: Grecia_1 Super League | Faltam: 292 min
#      Prob=55.9% | Odd=2.3 | EV=+28.7%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Over 2.5       | Fortaleza CEIF vs Deportivo Pasto
#      Liga: Colombia_1 Liga BetPlay | Faltam: 3652 min
#      Prob=50.8% | Odd=2.5 | EV=+27.1%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Casa      | Várda SE vs Ferencváros
#      Liga: Hungria_1 NB I | Faltam: 367 min
#      Prob=23.5% | Odd=5.4 | EV=+26.7%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Over 2.5       | Boyacá Chicó vs Deportes Tolima
#      Liga: Colombia_1 Liga BetPlay | Faltam: 1852 min
#      Prob=49.9% | Odd=2.5 | EV=+24.7%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Over 2.5       | Independiente Rivadavia vs Rosario Central
#      Liga: Argentina_1 Liga Profesional | Faltam: 787 min
#      Prob=52.1% | Odd=2.38 | EV=+24.0%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ BTTS           | Boca Juniors vs Instituto
#      Liga: Argentina_1 Liga Profesional | Faltam: 652 min
#      Prob=53.8% | Odd=2.3 | EV=+23.8%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Fora      | Sarmiento vs Aldosivi
#      Liga: Argentina_1 Liga Profesional | Faltam: 382 min
#      Prob=32.5% | Odd=3.8 | EV=+23.3%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Over 2.5       | Levadiakos vs Atromitos
#      Liga: Grecia_1 Super League | Faltam: 292 min
#      Prob=56.1% | Odd=2.19 | EV=+22.9%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Over 2.5       | Atlético PR vs Coritiba
#      Liga: Brasileiro_A Serie A | Faltam: 412 min
#      Prob=55.9% | Odd=2.2 | EV=+22.9%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Fora      | Fortuna Düsseldorf vs Hertha BSC
#      Liga: Alemanha_2 2. Bundesliga | Faltam: 22 min
#      Prob=40.6% | Odd=3 | EV=+21.8%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Fora      | Athletic Club Bilbao vs Real Betis
#      Liga: Espanha_1 La Liga | Faltam: 322 min
#      Prob=35.3% | Odd=3.45 | EV=+21.8%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ BTTS           | Boyacá Chicó vs Deportes Tolima
#      Liga: Colombia_1 Liga BetPlay | Faltam: 1852 min
#      Prob=54.7% | Odd=2.22 | EV=+21.5%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Over 2.5       | Botev Vratsa vs Lokomotiv Plovdiv
#      Liga: Bulgaria_1 First League | Faltam: 202 min
#      Prob=51.6% | Odd=2.35 | EV=+21.4%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ BTTS           | CSKA Sofia vs Dobrudzha 1919
#      Liga: Bulgaria_1 First League | Faltam: 52 min
#      Prob=52.8% | Odd=2.3 | EV=+21.3%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Over 2.5       | Burgos CF vs Córdoba
#      Liga: Espanha_2 Segunda Division | Faltam: 52 min
#      Prob=53.7% | Odd=2.25 | EV=+20.9%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Casa      | Sint-Truiden vs Union Saint-Gilloise
#      Liga: Belgica_1 Pro League | Faltam: 322 min
#      Prob=35.0% | Odd=3.45 | EV=+20.8%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ BTTS           | Volos NFC vs PAOK
#      Liga: Grecia_1 Super League | Faltam: 292 min
#      Prob=52.5% | Odd=2.3 | EV=+20.8%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Casa      | Remo vs Bahia
#      Liga: Brasileiro_A Serie A | Faltam: 412 min
#      Prob=34.3% | Odd=3.5 | EV=+19.9%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Over 2.5       | Corinthians vs Flamengo
#      Liga: Brasileiro_A Serie A | Faltam: 682 min
#      Prob=53.3% | Odd=2.25 | EV=+19.9%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Over 2.5       | St. Pauli vs Freiburg
#      Liga: Alemanha_1 Bundesliga | Faltam: 262 min
#      Prob=52.0% | Odd=2.3 | EV=+19.6%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Fora      | Argentinos Juniors vs Platense
#      Liga: Argentina_1 Liga Profesional | Faltam: 787 min
#      Prob=22.6% | Odd=5.3 | EV=+19.6%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Fora      | Internacional vs Chapecoense
#      Liga: Brasileiro_A Serie A | Faltam: 562 min
#      Prob=18.4% | Odd=6.5 | EV=+19.5%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Over 2.5       | Deportivo Pereira vs Cúcuta Deportivo
#      Liga: Colombia_1 Liga BetPlay | Faltam: 3382 min
#      Prob=51.3% | Odd=2.33 | EV=+19.5%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ BTTS           | Estudiantes Río Cuarto vs River Plate
#      Liga: Argentina_1 Liga Profesional | Faltam: 517 min
#      Prob=55.3% | Odd=2.15 | EV=+18.9%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Fora      | Puskás vs Debrecen
#      Liga: Hungria_1 NB I | Faltam: 82 min
#      Prob=36.9% | Odd=3.2 | EV=+18.0%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Over 2.5       | Alianza Petrolera vs Deportivo Cali
#      Liga: Colombia_1 Liga BetPlay | Faltam: 532 min
#      Prob=50.2% | Odd=2.35 | EV=+18.0%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Casa      | Corinthians vs Flamengo
# ...
#      Liga: Portugal_1 Primeira Liga | Faltam: 98 min
#      Prob=50.0% | Odd=2.42 | EV=+21.1%
#      Movimento odd: 📈 +10.0%
#
#   ✅ Over 2.5       | Alianza Petrolera vs Deportivo Cali
#      Liga: Colombia_1 Liga BetPlay | Faltam: 128 min
#      Prob=50.2% | Odd=2.4 | EV=+20.5%
#      Movimento odd: 📈 +2.1%
#
#   ✅ BTTS           | Fortaleza CEIF vs Deportivo Pasto
#      Liga: Colombia_1 Liga BetPlay | Faltam: 3248 min
#      Prob=54.1% | Odd=2.22 | EV=+20.1%
#      Movimento odd: 📈 +12.7%
#
#   ✅ Back Fora      | Deportivo Riestra vs San Lorenzo
#      Liga: Argentina_1 Liga Profesional | Faltam: 4508 min
#      Prob=33.9% | Odd=3.54 | EV=+20.0%
#      Movimento odd: 📈 +4.1%
#
#   ✅ Back Fora      | Emmen vs Cambuur
#      Liga: Holanda_2 Eerste Divisie | Faltam: 2888 min
#      Prob=59.9% | Odd=2 | EV=+19.9%
#      Movimento odd: 📈 +8.1%
#
#   ✅ Back Casa      | Corinthians vs Flamengo
#      Liga: Brasileiro_A Serie A | Faltam: 278 min
#      Prob=37.3% | Odd=3.15 | EV=+17.6%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Fora      | Argentinos Juniors vs Platense
#      Liga: Argentina_1 Liga Profesional | Faltam: 383 min
#      Prob=22.6% | Odd=5.2 | EV=+17.3%
#      Movimento odd: ➡️ -1.9%
#
#   ✅ Over 2.5       | Boyacá Chicó vs Deportes Tolima
#      Liga: Colombia_1 Liga BetPlay | Faltam: 1448 min
#      Prob=49.9% | Odd=2.35 | EV=+17.2%
#      Movimento odd: 📉 -6.0%
#
#   ✅ BTTS           | Jaguares de Córdoba vs Rionegro Águilas
#      Liga: Colombia_1 Liga BetPlay | Faltam: 1708 min
#      Prob=53.7% | Odd=2.16 | EV=+16.1%
#      Movimento odd: 📈 +9.1%
#
#   ✅ Back Casa      | Vitória vs Mirassol
#      Liga: Brasileiro_A Serie A | Faltam: 158 min
#      Prob=44.5% | Odd=2.6 | EV=+15.8%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Over 2.5       | Junior vs Atlético Bucaramanga
#      Liga: Colombia_1 Liga BetPlay | Faltam: 3128 min
#      Prob=50.6% | Odd=2.27 | EV=+14.9%
#      Movimento odd: ➡️ +0.9%
#
#   ✅ Back Casa      | Estudiantes Río Cuarto vs River Plate
#      Liga: Argentina_1 Liga Profesional | Faltam: 113 min
#      Prob=16.9% | Odd=6.75 | EV=+14.3%
#      Movimento odd: ➡️ -0.3%
#
#   ✅ Back Fora      | Santa Fe vs Independiente Medellín
#      Liga: Colombia_1 Liga BetPlay | Faltam: 1578 min
#      Prob=34.4% | Odd=3.31 | EV=+14.0%
#      Movimento odd: ➡️ -1.2%
#
#   ✅ BTTS           | Boyacá Chicó vs Deportes Tolima
#      Liga: Colombia_1 Liga BetPlay | Faltam: 1448 min
#      Prob=54.7% | Odd=2.08 | EV=+13.9%
#      Movimento odd: 📉 -6.3%
#
#   ✅ Back Casa      | Remo vs Bahia
#      Liga: Brasileiro_A Serie A | Faltam: 8 min
#      Prob=34.3% | Odd=3.3 | EV=+13.1%
#      Movimento odd: 📉 -5.7%
#
#   ✅ Over 2.5       | Sporting Braga vs Porto
#      Liga: Portugal_1 Primeira Liga | Faltam: 98 min
#      Prob=50.1% | Odd=2.25 | EV=+12.7%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Over 2.5       | América de Cali vs Llaneros
#      Liga: Colombia_1 Liga BetPlay | Faltam: 4688 min
#      Prob=52.4% | Odd=2.14 | EV=+12.1%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ BTTS           | América de Cali vs Llaneros
#      Liga: Colombia_1 Liga BetPlay | Faltam: 4688 min
#      Prob=53.3% | Odd=2.1 | EV=+11.9%
#      Movimento odd: 📉 -2.3%
#
#   ✅ BTTS           | Independiente Rivadavia vs Rosario Central
#      Liga: Argentina_1 Liga Profesional | Faltam: 383 min
#      Prob=54.2% | Odd=2.05 | EV=+11.1%
#      Movimento odd: ➡️ +1.0%
#
#   ✅ Back Fora      | Augsburg vs Stuttgart
#      Liga: Alemanha_1 Bundesliga | Faltam: -21 min
#      Prob=53.4% | Odd=2.07 | EV=+10.5%
#      Movimento odd: ➡️ +1.0%
#
#   ✅ Back Fora      | Doncaster Rovers vs Port Vale
#      Liga: Inglaterra_3 League One | Faltam: 2933 min
#      Prob=24.7% | Odd=4.45 | EV=+9.7%
#      Movimento odd: 📈 +14.1%
#
#   ✅ Back Casa      | Independiente Rivadavia vs Rosario Central
#      Liga: Argentina_1 Liga Profesional | Faltam: 383 min
#      Prob=40.0% | Odd=2.7 | EV=+7.9%
#      Movimento odd: 📈 +8.0%
#
#   ✅ BTTS           | Deportivo Pereira vs Cúcuta Deportivo
#      Liga: Colombia_1 Liga BetPlay | Faltam: 2978 min
#      Prob=54.5% | Odd=1.97 | EV=+7.4%
#      Movimento odd: 📈 +8.2%
#
#   ✅ BTTS           | Vitória vs Mirassol
#      Liga: Brasileiro_A Serie A | Faltam: 158 min
#      Prob=54.4% | Odd=1.97 | EV=+7.2%
#      Movimento odd: 📈 +6.5%
#
#   ✅ BTTS           | Alianza Petrolera vs Deportivo Cali
#      Liga: Colombia_1 Liga BetPlay | Faltam: 128 min
#      Prob=53.6% | Odd=2 | EV=+7.1%
#      Movimento odd: 📈 +2.6%
#
#   ✅ BTTS           | Corinthians vs Flamengo
#      Liga: Brasileiro_A Serie A | Faltam: 278 min
#      Prob=55.6% | Odd=1.92 | EV=+6.8%
#      Movimento odd: ➡️ -1.5%
#
#   ✅ Back Fora      | Internacional vs Chapecoense
#      Liga: Brasileiro_A Serie A | Faltam: 158 min
#      Prob=18.4% | Odd=5.8 | EV=+6.7%
#      Movimento odd: 📉 -10.8%
#
#   ✅ Over 2.5       | Jaguares de Córdoba vs Rionegro Águilas
#      Liga: Colombia_1 Liga BetPlay | Faltam: 1708 min
#      Prob=48.9% | Odd=2.15 | EV=+5.1%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Over 2.5       | Santa Fe vs Independiente Medellín
#      Liga: Colombia_1 Liga BetPlay | Faltam: 1578 min
#      Prob=51.5% | Odd=2.04 | EV=+5.0%
#      Movimento odd: 📈 +3.6%
#
#   ✅ Back Fora      | CD Castellón vs Cultural y Deportiva Leonesa
#      Liga: Espanha_2 Segunda Division | Faltam: 1478 min
#      Prob=14.7% | Odd=7.1 | EV=+4.3%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Over 2.5       | Vitória vs Mirassol
#      Liga: Brasileiro_A Serie A | Faltam: 158 min
#      Prob=50.1% | Odd=2.07 | EV=+3.7%
#      Movimento odd: 📉 -5.9%
#
#   ✅ Over 2.5       | Doncaster Rovers vs Port Vale
#      Liga: Inglaterra_3 League One | Faltam: 2933 min
#      Prob=51.7% | Odd=2 | EV=+3.4%
#      Movimento odd: 📈 +6.4%
#
#   ✅ BTTS           | Santa Fe vs Independiente Medellín
#      Liga: Colombia_1 Liga BetPlay | Faltam: 1578 min
#      Prob=55.2% | Odd=1.87 | EV=+3.1%
#      Movimento odd: 📈 +4.5%
#
# [15:51:54] ✅ CSV atualizado → rodada_atual_v3.csv
#
# ── Ciclo 16 ──────────────────────────────
# [16:22:32] 🔄 Atualizando 39 jogos...
#
# 🚨🚨🚨 ALERTAS DE VALOR 🚨🚨🚨
#   ✅ Back Fora      | Huracán vs Barracas Central
#      Liga: Argentina_1 Liga Profesional | Faltam: 1732 min
#      Prob=33.9% | Odd=5.5 | EV=+86.4%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Over 2.5       | Deportivo Riestra vs San Lorenzo
#      Liga: Argentina_1 Liga Profesional | Faltam: 4477 min
#      Prob=50.9% | Odd=3.38 | EV=+72.0%
#      Movimento odd: 📉 -15.5%
#
#   ✅ Back Fora      | Boca Juniors vs Instituto
#      Liga: Argentina_1 Liga Profesional | Faltam: 217 min
#      Prob=29.6% | Odd=5.4 | EV=+59.9%
#      Movimento odd: 📈 +2.9%
#
#   ✅ BTTS           | Deportivo Riestra vs San Lorenzo
#      Liga: Argentina_1 Liga Profesional | Faltam: 4477 min
#      Prob=53.6% | Odd=2.91 | EV=+56.1%
#      Movimento odd: 📈 +11.9%
#
#   ✅ Back Fora      | Estudiantes vs Central Córdoba SdE
#      Liga: Argentina_1 Liga Profesional | Faltam: 1597 min
#      Prob=22.2% | Odd=7 | EV=+55.7%
#      Movimento odd: 📉 -2.8%
#
#   ✅ Back Fora      | Cruzeiro vs Santos
#      Liga: Brasileiro_A Serie A | Faltam: -22 min
#      Prob=30.2% | Odd=5 | EV=+50.8%
#      Movimento odd: 📈 +3.7%
#
#   ✅ Over 2.5       | Huracán vs Barracas Central
#      Liga: Argentina_1 Liga Profesional | Faltam: 1732 min
#      Prob=51.3% | Odd=2.8 | EV=+43.7%
#      Movimento odd: 📉 -6.7%
#
#   ✅ Over 2.5       | Argentinos Juniors vs Platense
#      Liga: Argentina_1 Liga Profesional | Faltam: 352 min
#      Prob=52.7% | Odd=2.71 | EV=+42.9%
#      Movimento odd: 📈 +3.8%
#
#   ✅ BTTS           | Argentinos Juniors vs Platense
#      Liga: Argentina_1 Liga Profesional | Faltam: 352 min
#      Prob=52.6% | Odd=2.68 | EV=+41.0%
#      Movimento odd: 📈 +9.4%
#
#   ✅ Back Fora      | Fortaleza CEIF vs Deportivo Pasto
#      Liga: Colombia_1 Liga BetPlay | Faltam: 3217 min
#      Prob=42.8% | Odd=3.2 | EV=+36.8%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ BTTS           | Huracán vs Barracas Central
#      Liga: Argentina_1 Liga Profesional | Faltam: 1732 min
#      Prob=54.0% | Odd=2.5 | EV=+35.1%
#      Movimento odd: 📉 -4.2%
#
#   ✅ Over 2.5       | Estudiantes Río Cuarto vs River Plate
#      Liga: Argentina_1 Liga Profesional | Faltam: 82 min
#      Prob=48.5% | Odd=2.69 | EV=+30.4%
#      Movimento odd: 📈 +14.5%
#
#   ✅ Over 2.5       | Estudiantes vs Central Córdoba SdE
#      Liga: Argentina_1 Liga Profesional | Faltam: 1597 min
#      Prob=52.4% | Odd=2.48 | EV=+29.9%
#      Movimento odd: ➡️ -0.8%
#
#   ✅ BTTS           | Estudiantes vs Central Córdoba SdE
#      Liga: Argentina_1 Liga Profesional | Faltam: 1597 min
#      Prob=53.0% | Odd=2.45 | EV=+29.8%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Fora      | Jaguares de Córdoba vs Rionegro Águilas
#      Liga: Colombia_1 Liga BetPlay | Faltam: 1677 min
#      Prob=49.4% | Odd=2.62 | EV=+29.3%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Fora      | Junior vs Atlético Bucaramanga
#      Liga: Colombia_1 Liga BetPlay | Faltam: 3097 min
#      Prob=36.8% | Odd=3.5 | EV=+28.6%
#      Movimento odd: 📉 -4.1%
#
#   ✅ BTTS           | Estudiantes Río Cuarto vs River Plate
#      Liga: Argentina_1 Liga Profesional | Faltam: 82 min
#      Prob=55.3% | Odd=2.3 | EV=+27.1%
#      Movimento odd: 📈 +7.0%
#
#   ✅ Over 2.5       | Fortaleza CEIF vs Deportivo Pasto
#      Liga: Colombia_1 Liga BetPlay | Faltam: 3217 min
#      Prob=50.8% | Odd=2.5 | EV=+27.1%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Fora      | Atlético PR vs Coritiba
#      Liga: Brasileiro_A Serie A | Faltam: -22 min
#      Prob=31.7% | Odd=4 | EV=+26.8%
#      Movimento odd: 📉 -7.4%
#
#   ✅ Over 2.5       | Corinthians vs Flamengo
#      Liga: Brasileiro_A Serie A | Faltam: 247 min
#      Prob=53.3% | Odd=2.35 | EV=+25.2%
#      Movimento odd: 📈 +4.4%
#
#   ✅ Over 2.5       | Atlético PR vs Coritiba
#      Liga: Brasileiro_A Serie A | Faltam: -22 min
#      Prob=55.9% | Odd=2.23 | EV=+24.6%
#      Movimento odd: ➡️ +1.4%
#
#   ✅ Over 2.5       | Independiente Rivadavia vs Rosario Central
#      Liga: Argentina_1 Liga Profesional | Faltam: 352 min
#      Prob=52.1% | Odd=2.39 | EV=+24.5%
#      Movimento odd: ➡️ +0.4%
#
#   ✅ Over 2.5       | Deportivo Pereira vs Cúcuta Deportivo
#      Liga: Colombia_1 Liga BetPlay | Faltam: 2947 min
#      Prob=51.3% | Odd=2.39 | EV=+22.6%
#      Movimento odd: 📈 +2.6%
#
#   ✅ Over 2.5       | Boca Juniors vs Instituto
#      Liga: Argentina_1 Liga Profesional | Faltam: 217 min
#      Prob=50.5% | Odd=2.42 | EV=+22.1%
#      Movimento odd: 📉 -6.9%
#
#   ✅ Back Fora      | América de Cali vs Llaneros
#      Liga: Colombia_1 Liga BetPlay | Faltam: 4657 min
#      Prob=23.2% | Odd=5.25 | EV=+21.6%
#      Movimento odd: 📈 +5.0%
#
#   ✅ BTTS           | Boca Juniors vs Instituto
#      Liga: Argentina_1 Liga Profesional | Faltam: 217 min
#      Prob=53.8% | Odd=2.25 | EV=+21.1%
#      Movimento odd: 📉 -2.2%
#
#   ✅ Back Fora      | Sporting Braga vs Porto
#      Liga: Portugal_1 Primeira Liga | Faltam: 67 min
#      Prob=50.0% | Odd=2.42 | EV=+21.1%
#      Movimento odd: 📈 +10.0%
#
#   ✅ Over 2.5       | Alianza Petrolera vs Deportivo Cali
#      Liga: Colombia_1 Liga BetPlay | Faltam: 97 min
#      Prob=50.2% | Odd=2.4 | EV=+20.5%
#      Movimento odd: 📈 +2.1%
#
#   ✅ BTTS           | Fortaleza CEIF vs Deportivo Pasto
#      Liga: Colombia_1 Liga BetPlay | Faltam: 3217 min
#      Prob=54.1% | Odd=2.22 | EV=+20.1%
#      Movimento odd: 📈 +12.7%
#
#   ✅ Back Fora      | Deportivo Riestra vs San Lorenzo
#      Liga: Argentina_1 Liga Profesional | Faltam: 4477 min
#      Prob=33.9% | Odd=3.54 | EV=+20.0%
#      Movimento odd: 📈 +4.1%
#
#   ✅ Back Fora      | Emmen vs Cambuur
#      Liga: Holanda_2 Eerste Divisie | Faltam: 2857 min
#      Prob=59.9% | Odd=2 | EV=+19.9%
#      Movimento odd: 📈 +8.1%
#
#   ✅ Back Casa      | Corinthians vs Flamengo
#      Liga: Brasileiro_A Serie A | Faltam: 247 min
#      Prob=37.3% | Odd=3.15 | EV=+17.6%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Fora      | Argentinos Juniors vs Platense
#      Liga: Argentina_1 Liga Profesional | Faltam: 352 min
#      Prob=22.6% | Odd=5.2 | EV=+17.3%
#      Movimento odd: ➡️ -1.9%
#
#   ✅ Over 2.5       | Boyacá Chicó vs Deportes Tolima
#      Liga: Colombia_1 Liga BetPlay | Faltam: 1417 min
#      Prob=49.9% | Odd=2.35 | EV=+17.2%
#      Movimento odd: 📉 -6.0%
#
#   ✅ BTTS           | Jaguares de Córdoba vs Rionegro Águilas
#      Liga: Colombia_1 Liga BetPlay | Faltam: 1677 min
#      Prob=53.7% | Odd=2.16 | EV=+16.1%
#      Movimento odd: 📈 +9.1%
#
#   ✅ Back Casa      | Vitória vs Mirassol
#      Liga: Brasileiro_A Serie A | Faltam: 127 min
#      Prob=44.5% | Odd=2.6 | EV=+15.8%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Over 2.5       | Junior vs Atlético Bucaramanga
#      Liga: Colombia_1 Liga BetPlay | Faltam: 3097 min
#      Prob=50.6% | Odd=2.27 | EV=+14.9%
#      Movimento odd: ➡️ +0.9%
#
#   ✅ Back Casa      | Estudiantes Río Cuarto vs River Plate
#      Liga: Argentina_1 Liga Profesional | Faltam: 82 min
#      Prob=16.9% | Odd=6.75 | EV=+14.3%
#      Movimento odd: ➡️ -0.3%
#
#   ✅ Back Fora      | Santa Fe vs Independiente Medellín
#      Liga: Colombia_1 Liga BetPlay | Faltam: 1547 min
#      Prob=34.4% | Odd=3.31 | EV=+14.0%
#      Movimento odd: ➡️ -1.2%
#
#   ✅ BTTS           | Boyacá Chicó vs Deportes Tolima
#      Liga: Colombia_1 Liga BetPlay | Faltam: 1417 min
#      Prob=54.7% | Odd=2.08 | EV=+13.9%
#      Movimento odd: 📉 -6.3%
#
#   ✅ Back Casa      | Remo vs Bahia
#      Liga: Brasileiro_A Serie A | Faltam: -22 min
#      Prob=34.3% | Odd=3.3 | EV=+13.1%
#      Movimento odd: 📉 -5.7%
#
#   ✅ Over 2.5       | Sporting Braga vs Porto
#      Liga: Portugal_1 Primeira Liga | Faltam: 67 min
#      Prob=50.1% | Odd=2.25 | EV=+12.7%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Over 2.5       | América de Cali vs Llaneros
#      Liga: Colombia_1 Liga BetPlay | Faltam: 4657 min
#      Prob=52.4% | Odd=2.14 | EV=+12.1%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ BTTS           | América de Cali vs Llaneros
#      Liga: Colombia_1 Liga BetPlay | Faltam: 4657 min
#      Prob=53.3% | Odd=2.1 | EV=+11.9%
#      Movimento odd: 📉 -2.3%
#
#   ✅ BTTS           | Independiente Rivadavia vs Rosario Central
#      Liga: Argentina_1 Liga Profesional | Faltam: 352 min
#      Prob=54.2% | Odd=2.05 | EV=+11.1%
#      Movimento odd: ➡️ +1.0%
#
#   ✅ Back Fora      | Doncaster Rovers vs Port Vale
#      Liga: Inglaterra_3 League One | Faltam: 2902 min
#      Prob=24.7% | Odd=4.45 | EV=+9.7%
#      Movimento odd: 📈 +14.1%
#
#   ✅ Back Casa      | Independiente Rivadavia vs Rosario Central
#      Liga: Argentina_1 Liga Profesional | Faltam: 352 min
#      Prob=40.0% | Odd=2.7 | EV=+7.9%
#      Movimento odd: 📈 +8.0%
#
#   ✅ BTTS           | Deportivo Pereira vs Cúcuta Deportivo
#      Liga: Colombia_1 Liga BetPlay | Faltam: 2947 min
#      Prob=54.5% | Odd=1.97 | EV=+7.4%
#      Movimento odd: 📈 +8.2%
#
#   ✅ BTTS           | Alianza Petrolera vs Deportivo Cali
#      Liga: Colombia_1 Liga BetPlay | Faltam: 97 min
#      Prob=53.6% | Odd=2 | EV=+7.1%
#      Movimento odd: 📈 +2.6%
#
#   ✅ BTTS           | Corinthians vs Flamengo
#      Liga: Brasileiro_A Serie A | Faltam: 247 min
#      Prob=55.6% | Odd=1.92 | EV=+6.8%
#      Movimento odd: ➡️ -1.5%
#
#   ✅ Back Fora      | Internacional vs Chapecoense
#      Liga: Brasileiro_A Serie A | Faltam: 127 min
#      Prob=18.4% | Odd=5.8 | EV=+6.7%
#      Movimento odd: 📉 -10.8%
#
#   ✅ BTTS           | Vitória vs Mirassol
#      Liga: Brasileiro_A Serie A | Faltam: 127 min
#      Prob=54.4% | Odd=1.95 | EV=+6.2%
#      Movimento odd: 📈 +5.4%
#
#   ✅ Over 2.5       | Jaguares de Córdoba vs Rionegro Águilas
#      Liga: Colombia_1 Liga BetPlay | Faltam: 1677 min
#      Prob=48.9% | Odd=2.15 | EV=+5.1%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Over 2.5       | Santa Fe vs Independiente Medellín
#      Liga: Colombia_1 Liga BetPlay | Faltam: 1547 min
#      Prob=51.5% | Odd=2.04 | EV=+5.0%
#      Movimento odd: 📈 +3.6%
#
#   ✅ Back Fora      | CD Castellón vs Cultural y Deportiva Leonesa
#      Liga: Espanha_2 Segunda Division | Faltam: 1447 min
#      Prob=14.7% | Odd=7.1 | EV=+4.3%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Over 2.5       | Vitória vs Mirassol
#      Liga: Brasileiro_A Serie A | Faltam: 127 min
#      Prob=50.1% | Odd=2.07 | EV=+3.7%
#      Movimento odd: 📉 -5.9%
#
#   ✅ Over 2.5       | Doncaster Rovers vs Port Vale
#      Liga: Inglaterra_3 League One | Faltam: 2902 min
#      Prob=51.7% | Odd=2 | EV=+3.4%
#      Movimento odd: 📈 +6.4%
#
#   ✅ BTTS           | Santa Fe vs Independiente Medellín
#      Liga: Colombia_1 Liga BetPlay | Faltam: 1547 min
#      Prob=55.2% | Odd=1.87 | EV=+3.1%
#      Movimento odd: 📈 +4.5%
#
# [16:22:32] ✅ CSV atualizado → rodada_atual_v3.csv

# %%
# ── Parar o scheduler ────────────────────────────────────────────────────────
# Rode esta célula para parar o loop sem precisar reiniciar o kernel
_scheduler_ativo = False
print("🔴 Scheduler parado")
