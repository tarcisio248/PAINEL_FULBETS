# %% [markdown]
# # 📅 Rodada Atual v3 — Probabilidades + EV em Tempo Real
# ### Notebook 2 de 2: Jogos futuros · Prob base · Odds D-2 · Scheduler automático
#
# **Fluxo de uso:**
# ```
# MANHÃ (1x por dia)
#   └── Rodar Células 1→6
#   └── Gera rodada_atual_v3.csv com prob_base SEM odd
#   └── Salva odds_d2 (referência para medir movimento)
#
# 30 MIN ANTES DE CADA JOGO (automático)
#   └── Scheduler (Célula 7) roda em background
#   └── Busca odd atual da API
#   └── Calcula EV = prob_base × odd_atual - 1
#   └── Calcula movimento = odd_d2 - odd_atual
#   └── Atualiza rodada_atual_v3.csv
#   └── Alerta no terminal quando EV > 3%
# ```
#
# **Dependências:**
# - `modelo_v3.pkl` — gerado pelo Notebook 1
# - `elo_ratings.json` — gerado pelo Notebook 1

# %%
import requests, pandas as pd, numpy as np
import time, os, json, pickle, warnings
from datetime import datetime, timedelta
import pytz
warnings.filterwarnings("ignore")

# ── Configuração ──────────────────────────────────────────────────────────────
API_KEY    = "033f6d5fc7b707b144fbd2c28898c1540eb066ee9efea6c038d740ffedeacb5f"
BASE_URL   = "https://api.football-data-api.com"
PKL_FILE   = "modelo_v3.pkl"
ELO_FILE   = "elo_ratings.json"
RODADA_CSV = "rodada_atual_v3.csv"
JANELA     = 10
ELO_HOME   = 50
ELO_BASE   = 1500
EV_MIN     = 0.03        # 3% de edge mínimo
SLEEP      = 0.5
MAX_PAGE   = 300

# Fuso horário (ajuste para o seu)
TZ = pytz.timezone("America/Sao_Paulo")

# ── Ligas e season_ids ────────────────────────────────────────────────────────
LIGAS = {
    "Alemanha_1 Bundesliga":        14968,
    "Alemanha_2 2. Bundesliga":     14931,
    "Alemanha_3 3. Liga":           14977,
    "Australia_1 A-League":         16036,
    "Belgica_1 Pro League":         14937,
    "Bulgaria_1 First League":      15056,
    "Croacia_1 HNL":                15053,
    "Escocia_1 Premiership":        15000,
    "Espanha_1 La Liga":            14956,
    "Espanha_2 Segunda Division":   15066,
    "Franca_1 Ligue 1":             14932,
    "Franca_2 Ligue 2":             14954,
    "Grecia_1 Super League":        15163,
    "Holanda_1 Eredivisie":         14936,
    "Holanda_2 Eerste Divisie":     14987,
    "Hungria_1 NB I":               14963,
    "Inglaterra_1 Premier League":  15050,
    "Inglaterra_2 Championship":    14930,
    "Inglaterra_3 League One":      14934,
    "Italia_1 Serie A":             15068,
    "Italia_2 Serie B":             15632,
    "Portugal_1 Primeira Liga":     15115,
    "Rep_Tcheca_1 Czech Liga":      14973,
    "Turquia_1 Super Lig":          14972,
    "Brasileiro_A Serie A":         16544,
    "Argentina_1 Liga Profesional": 16571,
    "Chile_1 Primera Division":     16615,
    "Colombia_1 Liga BetPlay":      16614,
}

print(f"✅ Configuração carregada | {len(LIGAS)} ligas")
print(f"   EV mínimo: {EV_MIN*100:.0f}% | Janela: N{JANELA}")
# Out:
# ✅ Configuração carregada | 28 ligas
#    EV mínimo: 3% | Janela: N10

# %%
# ── Carregar modelo treinado e ratings ELO ───────────────────────────────────

# Modelo
if not os.path.exists(PKL_FILE):
    raise FileNotFoundError(f"❌ {PKL_FILE} não encontrado. Rode o Notebook 1 primeiro.")
with open(PKL_FILE, "rb") as f:
    modelos = pickle.load(f)
print(f"✅ Modelo carregado: {len(modelos)} mercados")
for label, m in modelos.items():
    print(f"   {m['nome']:<16} AUC={m['auc']:.3f}")

# ELO ratings
if not os.path.exists(ELO_FILE):
    raise FileNotFoundError(f"❌ {ELO_FILE} não encontrado. Rode o Notebook 1 primeiro.")
with open(ELO_FILE, "r") as f:
    elo_ratings = json.load(f)
print(f"\n✅ ELO carregado: {len(elo_ratings)} times")

def get_elo(league, team_id):
    return elo_ratings.get(f"{league}|{str(team_id)}", ELO_BASE)
# Out:
# ✅ Modelo carregado: 6 mercados
#    Back Casa        AUC=0.645
#    Back Fora        AUC=0.645
#    BTTS             AUC=0.501
#    Over 2.5         AUC=0.509
#    Over 0.5 HT      AUC=0.508
#    BTTS HT          AUC=0.509
#
# ✅ ELO carregado: 551 times

# %%
# ── Buscar jogos futuros da API ───────────────────────────────────────────────
# Busca jogos com status != complete (agendados/ao vivo)
# Janela: hoje + próximos 7 dias

def buscar_jogos_futuros(liga_nome, season_id):
    jogos, page = [], 1
    agora  = int(datetime.now(TZ).timestamp())
    limite = agora + 7 * 86400  # 7 dias à frente

    while True:
        try:
            resp = requests.get(
                f"{BASE_URL}/league-matches",
                params={"key": API_KEY, "season_id": season_id,
                        "max_per_page": MAX_PAGE, "page": page},
                timeout=20
            )
            if resp.status_code == 429:
                print("  ⚠️  Rate limit — aguardando 60s...")
                time.sleep(60); continue
            resp.raise_for_status()
            data = resp.json()
        except Exception as e:
            print(f"  ❌ {liga_nome}: {e}"); break

        matches = data.get("data", [])
        if not matches: break

        for m in matches:
            status     = m.get("status", "")
            date_unix  = m.get("date_unix", 0) or 0

            # Só jogos futuros dentro da janela
            if status == "complete": continue
            if date_unix < agora or date_unix > limite: continue

            hid = m.get("homeID")
            aid = m.get("awayID")
            hid = str(int(hid)) if hid is not None else "0"
            aid = str(int(aid)) if aid is not None else "0"

            jogos.append({
                "fixture_id":    str(m.get("id", "")),
                "league":        liga_nome,
                "season_id":     season_id,
                "date_unix":     date_unix,
                "home_id":       hid,
                "away_id":       aid,
                "home_team":     m.get("home_name", ""),
                "away_team":     m.get("away_name", ""),
                "status":        status,
                # Odds D-2 (momento da coleta matinal)
                "odd_home_d2":   m.get("odds_ft_1"),
                "odd_draw_d2":   m.get("odds_ft_x"),
                "odd_away_d2":   m.get("odds_ft_2"),
                "odd_btts_d2":   m.get("odds_btts_yes"),
                "odd_over25_d2": m.get("odds_ft_over25"),
                # XG pré-jogo (disponível da API antes do jogo)
                "xg_home_pre":   m.get("team_a_xg_prematch"),
                "xg_away_pre":   m.get("team_b_xg_prematch"),
                "ppg_home":      m.get("pre_match_home_ppg"),
                "ppg_away":      m.get("pre_match_away_ppg"),
            })

        pager = data.get("pager", {})
        if page >= pager.get("max_page", pager.get("total_pages", 1)): break  # API usa 'max_page'
        page += 1
        time.sleep(SLEEP)
    return jogos

# Executar busca
print("🔍 Buscando jogos futuros (próximos 7 dias)...")
todos = []
for liga_nome, season_id in LIGAS.items():
    jogos = buscar_jogos_futuros(liga_nome, season_id)
    if jogos:
        print(f"  📅 {liga_nome}: {len(jogos)} jogos")
    todos.extend(jogos)
    time.sleep(SLEEP)

df_jogos = pd.DataFrame(todos) if todos else pd.DataFrame()
print(f"\n✅ Total: {len(df_jogos)} jogos nos próximos 7 dias")
if len(df_jogos) > 0:
    df_jogos["datahora"] = pd.to_datetime(df_jogos["date_unix"], unit="s")                               .dt.tz_localize("UTC").dt.tz_convert(TZ)                               .dt.strftime("%Y-%m-%d %H:%M")
    display(df_jogos[["datahora","league","home_team","away_team",
                       "odd_home_d2","odd_away_d2","xg_home_pre","xg_away_pre"]].head(10))
# Out:
# 🔍 Buscando jogos futuros (próximos 7 dias)...
#   📅 Alemanha_1 Bundesliga: 8 jogos
#   📅 Alemanha_2 2. Bundesliga: 9 jogos
#   📅 Alemanha_3 3. Liga: 8 jogos
#   📅 Australia_1 A-League: 6 jogos
#   📅 Belgica_1 Pro League: 4 jogos
#   📅 Bulgaria_1 First League: 5 jogos
#   📅 Croacia_1 HNL: 3 jogos
#   📅 Escocia_1 Premiership: 5 jogos
#   📅 Espanha_1 La Liga: 6 jogos
#   📅 Espanha_2 Segunda Division: 19 jogos
#   📅 Franca_1 Ligue 1: 5 jogos
#   📅 Franca_2 Ligue 2: 8 jogos
#   📅 Grecia_1 Super League: 7 jogos
#   📅 Holanda_1 Eredivisie: 8 jogos
#   📅 Holanda_2 Eerste Divisie: 10 jogos
#   📅 Hungria_1 NB I: 4 jogos
#   📅 Inglaterra_2 Championship: 11 jogos
#   📅 Inglaterra_3 League One: 11 jogos
#   📅 Italia_1 Serie A: 4 jogos
#   📅 Portugal_1 Primeira Liga: 7 jogos
#   📅 Rep_Tcheca_1 Czech Liga: 7 jogos
#   📅 Turquia_1 Super Lig: 6 jogos
#   📅 Brasileiro_A Serie A: 14 jogos
#   📅 Argentina_1 Liga Profesional: 11 jogos
#   📅 Chile_1 Primera Division: 5 jogos
#   📅 Colombia_1 Liga BetPlay: 16 jogos
#
# ✅ Total: 207 jogos nos próximos 7 dias
#            datahora                    league            home_team  \
# 0  2026-04-04 10:30     Alemanha_1 Bundesliga             Freiburg
# 1  2026-04-04 10:30     Alemanha_1 Bundesliga  Borussia M'gladbach
# 2  2026-04-04 10:30     Alemanha_1 Bundesliga         Hamburger SV
# 3  2026-04-04 13:30     Alemanha_1 Bundesliga            Stuttgart
# 4  2026-04-04 10:30     Alemanha_1 Bundesliga     Bayer Leverkusen
# 5  2026-04-05 10:30     Alemanha_1 Bundesliga         Union Berlin
# 6  2026-04-04 10:30     Alemanha_1 Bundesliga        Werder Bremen
# 7  2026-04-04 10:30     Alemanha_1 Bundesliga           Hoffenheim
# 8  2026-04-04 08:00  Alemanha_2 2. Bundesliga       Kaiserslautern
# 9  2026-04-05 08:30  Alemanha_2 2. Bundesliga        Holstein Kiel
#
#             away_team  odd_home_d2  odd_away_d2  xg_home_pre  xg_away_pre
# 0      Bayern München         8.10         1.40         1.65         2.11
# 1          Heidenheim         1.63         5.79         1.31         1.16
# 2            Augsburg         2.24         3.41         1.43         1.39
# 3   Borussia Dortmund         2.23         3.09         1.75         1.50
# 4           Wolfsburg         1.51         6.40         1.79         1.06
# 5           St. Pauli         2.04         4.57         1.30         1.11
# 6          RB Leipzig         3.30         2.13         1.69         1.57
# 7            Mainz 05         1.73         5.02         1.87         1.14
# 8  Fortuna Düsseldorf         0.00         0.00         1.72         1.48
# 9     Preußen Münster         0.00         0.00         1.46         1.16

# %%
# ── Buscar features N10 dos times a partir da base histórica ─────────────────
# Pega os últimos N10 jogos de cada time da base histórica
# e calcula as médias que o modelo precisa

RAW_CSV = "raw_2526.csv"

if not os.path.exists(RAW_CSV):
    raise FileNotFoundError(f"❌ {RAW_CSV} não encontrado. Rode o Notebook 1 primeiro.")

df_hist = pd.read_csv(RAW_CSV, dtype={"home_id": str, "away_id": str})
df_hist["date_unix"] = pd.to_numeric(df_hist["date_unix"], errors="coerce")
df_hist = df_hist[df_hist["score_home"].notna()]  # só jogos encerrados
df_hist = df_hist.sort_values("date_unix")

def ultimos_n_jogos(df_hist, team_id, liga, n=10):
    """
    Retorna os últimos N jogos do time (como home ou away) numa liga.
    Considera perspectiva do time: gols_marcados = gols como home OU away.
    """
    mask_h = (df_hist["home_id"] == str(team_id)) & (df_hist["league"] == liga)
    mask_a = (df_hist["away_id"] == str(team_id)) & (df_hist["league"] == liga)

    jogos_h = df_hist[mask_h].copy()
    jogos_h["gols_marc"] = jogos_h["score_home"]
    jogos_h["gols_sof"]  = jogos_h["score_away"]
    jogos_h["gols_ht"]   = jogos_h["score_home_ht"].fillna(0)
    jogos_h["vitoria"]   = (jogos_h["score_home"] > jogos_h["score_away"]).astype(int)
    jogos_h["xg"]        = pd.to_numeric(jogos_h.get("xg_home", 0), errors="coerce").fillna(0)

    jogos_a = df_hist[mask_a].copy()
    jogos_a["gols_marc"] = jogos_a["score_away"]
    jogos_a["gols_sof"]  = jogos_a["score_home"]
    jogos_a["gols_ht"]   = jogos_a["score_away_ht"].fillna(0)
    jogos_a["vitoria"]   = (jogos_a["score_away"] > jogos_a["score_home"]).astype(int)
    jogos_a["xg"]        = pd.to_numeric(jogos_a.get("xg_away", 0), errors="coerce").fillna(0)

    todos = pd.concat([jogos_h, jogos_a]).sort_values("date_unix").tail(n)
    if len(todos) == 0:
        return {}

    total_gols = todos["score_home"] + todos["score_away"]
    return {
        "n_jogos":       len(todos),
        "avg_xg":        todos["xg"].mean(),
        "pct_vitoria":   todos["vitoria"].mean(),
        "gols_marc":     todos["gols_marc"].mean(),
        "gols_sof":      todos["gols_sof"].mean(),
        "gols_ht":       todos["gols_ht"].mean(),
        "pct_btts":      ((todos["score_home"]>0)&(todos["score_away"]>0)).mean(),
        "pct_over25":    (total_gols > 2.5).mean(),
        "pct_over05ht":  ((todos["score_home_ht"].fillna(0)+todos["score_away_ht"].fillna(0))>0.5).mean(),
    }

# Calcular features N10 para cada time dos jogos futuros
print(f"⚙️  Calculando features N{JANELA} para {len(df_jogos)} jogos...")

features_jogos = []
for _, jogo in df_jogos.iterrows():
    fh = ultimos_n_jogos(df_hist, jogo["home_id"], jogo["league"], JANELA)
    fa = ultimos_n_jogos(df_hist, jogo["away_id"], jogo["league"], JANELA)

    # ELO pré-jogo
    elo_h = get_elo(jogo["league"], jogo["home_id"])
    elo_a = get_elo(jogo["league"], jogo["away_id"])

    # PPG
    ppg_h = float(jogo.get("ppg_home") or 0)
    ppg_a = float(jogo.get("ppg_away") or 0)

    # XG pré-jogo
    xg_pre_h = float(jogo.get("xg_home_pre") or 0)
    xg_pre_a = float(jogo.get("xg_away_pre") or 0)

    features_jogos.append({
        "fixture_id":       jogo["fixture_id"],
        # Features do modelo
        "elo_delta":        elo_h + ELO_HOME - elo_a,
        "xg_n10_diff":      fh.get("avg_xg",0)      - fa.get("avg_xg",0),
        "xg_pre_diff":      xg_pre_h                 - xg_pre_a,
        "pct_vit_diff":     fh.get("pct_vitoria",0)  - fa.get("pct_vitoria",0),
        "ppg_diff":         ppg_h                    - ppg_a,
        "gols_marc_diff":   fh.get("gols_marc",0)    - fa.get("gols_marc",0),
        "gols_sof_diff":    fh.get("gols_sof",0)     - fa.get("gols_sof",0),
        # Dados extras para o painel
        "n10_home":         fh.get("n_jogos",0),
        "n10_away":         fa.get("n_jogos",0),
        "elo_home":         elo_h,
        "elo_away":         elo_a,
        "xg_home_n10":      fh.get("avg_xg",0),
        "xg_away_n10":      fa.get("avg_xg",0),
        "pct_vit_home":     fh.get("pct_vitoria",0),
        "pct_vit_away":     fa.get("pct_vitoria",0),
        "gols_marc_home":   fh.get("gols_marc",0),
        "gols_marc_away":   fa.get("gols_marc",0),
        "pct_over25_home":  fh.get("pct_over25",0),
        "pct_over25_away":  fa.get("pct_over25",0),
    })

df_feat_fut = pd.DataFrame(features_jogos)
df_jogos = df_jogos.merge(df_feat_fut, on="fixture_id", how="left")
print(f"✅ Features calculadas")
print(f"   Times sem histórico N{JANELA}: "
      f"{(df_jogos['n10_home']==0).sum() + (df_jogos['n10_away']==0).sum()} times")
display(df_jogos[["home_team","away_team","elo_delta","xg_n10_diff",
                   "xg_pre_diff","pct_vit_diff"]].head(10).round(3))
# Out:
# ⚙️  Calculando features N10 para 207 jogos...
# ✅ Features calculadas
#    Times sem histórico N10: 0 times
#              home_team           away_team  elo_delta  xg_n10_diff  \
# 0             Freiburg      Bayern München   -145.549       -0.851
# 1  Borussia M'gladbach          Heidenheim    159.399        0.082
# 2         Hamburger SV            Augsburg     48.816       -0.382
# 3            Stuttgart   Borussia Dortmund     -3.785       -0.161
# 4     Bayer Leverkusen           Wolfsburg    220.643        0.386
# 5         Union Berlin           St. Pauli     88.590       -0.020
# 6        Werder Bremen          RB Leipzig    -86.399       -0.072
# 7           Hoffenheim            Mainz 05    111.360        0.257
# 8       Kaiserslautern  Fortuna Düsseldorf     84.471       -0.293
# 9        Holstein Kiel     Preußen Münster     72.913        0.016
#
#    xg_pre_diff  pct_vit_diff
# 0        -0.46          -0.3
# 1         0.15           0.2
# 2         0.04          -0.2
# 3         0.25          -0.2
# 4         0.73           0.4
# 5         0.19          -0.1
# 6         0.12          -0.2
# 7         0.73           0.0
# 8         0.24           0.0
# 9         0.30           0.1

# %%
# ── Calcular probabilidades BASE (sem odd) ───────────────────────────────────
#
# A prob_base é calculada ANTES de olhar as odds.
# Isso garante que o modelo não fica viciado em odds atuais
# que podem mudar até o kickoff.
#
# A odd só entra no EV final (Célula 7 — scheduler).

FEATURES = ["elo_delta","xg_n10_diff","xg_pre_diff","pct_vit_diff",
            "ppg_diff","gols_marc_diff","gols_sof_diff"]

# Verificar quais jogos têm features completas
mask_ok = df_jogos[FEATURES].notna().all(axis=1)
print(f"Jogos com features completas: {mask_ok.sum()}/{len(df_jogos)}")

X = df_jogos.loc[mask_ok, FEATURES].values

for label, m_info in modelos.items():
    col_prob = m_info["col_prob"]
    scaler   = m_info["scaler"]
    model    = m_info["model"]

    X_sc  = scaler.transform(X)
    probs = model.predict_proba(X_sc)[:,1]
    df_jogos.loc[mask_ok, col_prob] = probs

# Calcular EV pré-jogo com odds D-2 (referência)
# EV definitivo virá do scheduler com odds do kickoff
for label, nome, odd_tipica, col_prob, col_ev in [
    ("label_home_win",  "Back Casa",   1.90, "prob_bc",      "ev_bc_d2"),
    ("label_away_win",  "Back Fora",   2.50, "prob_bf",      "ev_bf_d2"),
    ("label_btts",      "BTTS",        1.85, "prob_btts",    "ev_btts_d2"),
    ("label_over25",    "Over 2.5",    1.80, "prob_over25",  "ev_over25_d2"),
    ("label_over05ht",  "Over 0.5 HT", 1.40, "prob_o05ht",   "ev_o05ht_d2"),
    ("label_btts_ht",   "BTTS HT",     3.50, "prob_btts_ht", "ev_btts_ht_d2"),
]:
    odd_col = {"Back Casa":"odd_home_d2","Back Fora":"odd_away_d2",
               "BTTS":"odd_btts_d2","Over 2.5":"odd_over25_d2",
               "Over 0.5 HT":"odd_over25_d2","BTTS HT":"odd_btts_d2"}.get(nome)
    if odd_col and odd_col in df_jogos.columns:
        odd_vals = pd.to_numeric(df_jogos[odd_col], errors="coerce").fillna(odd_tipica)
        df_jogos[col_ev] = df_jogos[col_prob] * odd_vals - 1
    else:
        df_jogos[col_ev] = df_jogos[col_prob] * odd_tipica - 1

print("\n✅ Probabilidades base calculadas")
print("\n📊 Amostra — jogos com maior EV (Back Casa D-2):")
cols_show = ["datahora","league","home_team","away_team",
             "prob_bc","ev_bc_d2","elo_delta","xg_pre_diff"]
cols_show = [c for c in cols_show if c in df_jogos.columns]
top = df_jogos[cols_show].sort_values("ev_bc_d2", ascending=False).head(10)
display(top.round(3))
# Out:
# Jogos com features completas: 207/207
#
# ✅ Probabilidades base calculadas
#
# 📊 Amostra — jogos com maior EV (Back Casa D-2):
#              datahora                        league          home_team  \
# 29   2026-04-03 05:35          Australia_1 A-League    Adelaide United
# 161  2026-04-04 21:00          Brasileiro_A Serie A      Vasco da Gama
# 162  2026-04-02 21:30          Brasileiro_A Serie A         Bragantino
# 38   2026-04-04 13:30       Bulgaria_1 First League              Beroe
# 183  2026-04-02 20:30  Argentina_1 Liga Profesional   Talleres Córdoba
# 95   2026-04-05 09:30          Holanda_1 Eredivisie           Volendam
# 139  2026-04-05 10:00              Italia_1 Serie A          Cremonese
# 115  2026-04-03 11:00     Inglaterra_2 Championship  Charlton Athletic
# 74   2026-04-05 10:00              Franca_1 Ligue 1         Angers SCO
# 166  2026-04-02 19:00          Brasileiro_A Serie A        Chapecoense
#
#               away_team  prob_bc  ev_bc_d2  elo_delta  xg_pre_diff
# 29             Auckland    0.404     0.461     39.161         0.18
# 161            Botafogo    0.615     0.377     78.405         1.28
# 162            Flamengo    0.338     0.371    -26.109         0.25
# 38           CSKA Sofia    0.130     0.304   -144.834        -0.57
# 183        Boca Juniors    0.395     0.289     62.352        -0.03
# 95            Feyenoord    0.198     0.220    -83.059        -0.24
# 139             Bologna    0.290     0.216    -29.122        -0.05
# 115        Bristol City    0.448     0.201     76.221         0.13
# 74   Olympique Lyonnais    0.262     0.199    -34.500        -0.12
# 166    Atlético Mineiro    0.382     0.173     54.012         0.09

# %%
# ── Salvar rodada_atual_v3.csv ────────────────────────────────────────────────
# Este CSV é carregado pelo painel HTML e atualizado pelo scheduler

df_jogos.to_csv(RODADA_CSV, index=False)
print(f"💾 {RODADA_CSV} salvo!")
print(f"   {len(df_jogos)} jogos | {df_jogos['league'].nunique()} ligas")
print(f"   Prob cols: {[c for c in df_jogos.columns if c.startswith('prob_')]}")
print(f"   EV cols  : {[c for c in df_jogos.columns if c.startswith('ev_')]}")
print()

# Resumo de alertas D-2
print("🚨 ALERTAS D-2 — Jogos com EV > {:.0f}% (usando odds de hoje):".format(EV_MIN*100))
for col_ev, nome in [("ev_bc_d2","Back Casa"),("ev_bf_d2","Back Fora"),
                      ("ev_btts_d2","BTTS"),("ev_over25_d2","Over 2.5")]:
    if col_ev not in df_jogos.columns: continue
    alertas = df_jogos[df_jogos[col_ev] > EV_MIN].sort_values(col_ev, ascending=False)
    if len(alertas) > 0:
        print(f"\n  {nome} ({len(alertas)} jogos):")
        for _, r in alertas.head(5).iterrows():
            print(f"    {r.get('datahora','?')[:16]} | {r['home_team']} vs {r['away_team']}"
                  f" | EV={r[col_ev]*100:+.1f}%"
                  f" | prob={r[col_ev.replace('ev_','prob_').replace('_d2','')]*100:.1f}%"
                  if col_ev.replace('ev_','prob_').replace('_d2','') in r else
                  f"    {r.get('datahora','?')[:16]} | {r['home_team']} vs {r['away_team']}"
                  f" | EV={r[col_ev]*100:+.1f}%")

print("\n✅ Célula 6 concluída — pronto para o scheduler (Célula 7)")
print("   Dica: rodar Célula 7 nos dias de jogo para atualização automática")
# Out:
# 💾 rodada_atual_v3.csv salvo!
#    207 jogos | 26 ligas
#    Prob cols: ['prob_bc', 'prob_bf', 'prob_btts', 'prob_over25', 'prob_o05ht', 'prob_btts_ht']
#    EV cols  : ['ev_bc_d2', 'ev_bf_d2', 'ev_btts_d2', 'ev_over25_d2', 'ev_o05ht_d2', 'ev_btts_ht_d2']
#
# 🚨 ALERTAS D-2 — Jogos com EV > 3% (usando odds de hoje):
#
#   Back Casa (27 jogos):
#     2026-04-03 05:35 | Adelaide United vs Auckland | EV=+46.1% | prob=40.4%
#     2026-04-04 21:00 | Vasco da Gama vs Botafogo | EV=+37.7% | prob=61.5%
#     2026-04-02 21:30 | Bragantino vs Flamengo | EV=+37.1% | prob=33.8%
#     2026-04-04 13:30 | Beroe vs CSKA Sofia | EV=+30.4% | prob=13.0%
#     2026-04-02 20:30 | Talleres Córdoba vs Boca Juniors | EV=+28.9% | prob=39.5%
#
#   Back Fora (79 jogos):
#     2026-04-02 19:00 | Santos vs Remo | EV=+115.0% | prob=34.7%
#     2026-04-01 22:30 | Atlético Nacional vs Cúcuta Deportivo | EV=+110.6% | prob=15.2%
#     2026-04-01 20:00 | Cruzeiro vs Vitória | EV=+101.3% | prob=36.6%
#     2026-04-04 21:00 | Rosario Central vs Atlético Tucumán | EV=+94.7% | prob=23.0%
#     2026-04-03 17:30 | Coquimbo Unido vs Cobresal | EV=+86.3% | prob=26.1%
#
#   BTTS (12 jogos):
#     2026-03-31 14:00 | Aldosivi vs Argentinos Juniors | EV=+22.5% | prob=55.2%
#     2026-04-01 20:00 | Lanús vs Platense | EV=+19.8% | prob=54.4%
#     2026-04-01 22:30 | Atlético Nacional vs Cúcuta Deportivo | EV=+14.9% | prob=54.4%
#     2026-03-30 22:20 | Millonarios vs Fortaleza CEIF | EV=+10.4% | prob=53.9%
#     2026-04-01 18:10 | Alianza Petrolera vs Deportivo Pasto | EV=+9.7% | prob=54.3%
#
#   Over 2.5 (52 jogos):
#     2026-04-01 20:00 | Lanús vs Platense | EV=+39.1% | prob=52.7%
#     2026-04-04 15:45 | Lazio vs Parma | EV=+28.1% | prob=58.2%
#     2026-04-03 21:00 | Levadiakos vs Aris | EV=+27.8% | prob=58.1%
#     2026-04-01 20:00 | Bahia vs Atlético PR | EV=+26.0% | prob=60.0%
#     2026-04-04 17:30 | Independiente vs Racing Club | EV=+25.7% | prob=51.3%
#
# ✅ Célula 6 concluída — pronto para o scheduler (Célula 7)
#    Dica: rodar Célula 7 nos dias de jogo para atualização automática

# %%
# ── Scheduler — atualiza odds e EV a cada 30 minutos ─────────────────────────
#
# Como usar:
#   1. Rode esta célula nos dias de jogo
#   2. Ela roda em background no Jupyter
#   3. A cada 30 min busca odds atuais dos jogos que ainda não começaram
#   4. Recalcula EV com a odd do momento
#   5. Alerta no terminal quando EV > EV_MIN
#   6. Pressione o botão ■ (Stop) para parar
#
# Os arquivos rodada_atual_v3.csv são atualizados automaticamente
# O painel HTML lerá a versão mais recente

# ── Imports da célula (autossuficiente — pode rodar sem reiniciar kernel) ──
import threading
from datetime import datetime  # ← corrige AttributeError: module 'datetime' has no attribute 'now'
import time, os, requests, pandas as pd

INTERVALO_MIN = 30  # minutos entre atualizações

# ── Verificar variáveis obrigatórias das células anteriores ──────────────
for _var in ['API_KEY', 'BASE_URL', 'RODADA_CSV', 'EV_MIN', 'TZ']:
    if _var not in globals():
        raise NameError(f'⚠️  {_var!r} não definida — rode as Células 1 e 2 antes do scheduler')
_scheduler_ativo = True

def buscar_odd_atual(fixture_id, season_id):
    """Busca odd atual de um jogo específico via fixture_id."""
    try:
        resp = requests.get(
            f"{BASE_URL}/match",
            params={"key": API_KEY, "match_id": fixture_id},
            timeout=15
        )
        resp.raise_for_status()
        data = resp.json()
        m = data.get("data", {})
        if not m: return {}
        return {
            "odd_home_atual":   m.get("odds_ft_1"),
            "odd_draw_atual":   m.get("odds_ft_x"),
            "odd_away_atual":   m.get("odds_ft_2"),
            "odd_btts_atual":   m.get("odds_btts_yes"),
            "odd_over25_atual": m.get("odds_ft_over25"),
            "status":           m.get("status",""),
        }
    except:
        return {}

def calcular_ev_atual(prob, odd):
    """EV = prob × odd - 1. Retorna None se odd indisponível."""
    if not odd or odd <= 1.0: return None
    return prob * float(odd) - 1

def atualizar_ciclo():
    """Um ciclo completo de atualização de odds e EV."""
    agora_ts = int(datetime.now(TZ).timestamp())
    agora_str = datetime.now(TZ).strftime("%H:%M:%S")

    if not os.path.exists(RODADA_CSV):
        print(f"[{agora_str}] ❌ {RODADA_CSV} não encontrado")
        return

    df = pd.read_csv(RODADA_CSV, dtype={"fixture_id": str})
    # Só jogos que ainda não começaram (30 min de margem)
    pendentes = df[pd.to_numeric(df["date_unix"], errors="coerce") > agora_ts - 1800]

    if len(pendentes) == 0:
        print(f"[{agora_str}] ℹ️  Nenhum jogo pendente")
        return

    print(f"[{agora_str}] 🔄 Atualizando {len(pendentes)} jogos...")
    alertas = []

    for idx, jogo in pendentes.iterrows():
        fid     = str(jogo["fixture_id"])
        sid     = jogo.get("season_id", 0)
        odds_at = buscar_odd_atual(fid, sid)
        if not odds_at: continue
        time.sleep(0.3)

        # Atualizar status
        df.at[idx, "status"] = odds_at.get("status", df.at[idx, "status"])

        # Mapas de prob → odd atual → EV final
        mercado_map = [
            ("prob_bc",      "odd_home_atual",   "ev_bc",      "Back Casa",   "odd_home_d2"),
            ("prob_bf",      "odd_away_atual",   "ev_bf",      "Back Fora",   "odd_away_d2"),
            ("prob_btts",    "odd_btts_atual",   "ev_btts",    "BTTS",        "odd_btts_d2"),
            ("prob_over25",  "odd_over25_atual", "ev_over25",  "Over 2.5",    "odd_over25_d2"),
        ]

        for col_prob, col_odd_at, col_ev, nome, col_odd_d2 in mercado_map:
            if col_prob not in df.columns: continue
            prob     = float(df.at[idx, col_prob] or 0)
            odd_at   = odds_at.get(col_odd_at)
            odd_d2   = float(df.at[idx, col_odd_d2] or 0) if col_odd_d2 in df.columns else 0

            ev = calcular_ev_atual(prob, odd_at)
            if ev is None: continue

            df.at[idx, col_ev]              = ev
            df.at[idx, col_odd_at]          = odd_at

            # Movimento da odd (D-2 vs atual)
            if odd_d2 > 0 and odd_at:
                mov = ((float(odd_at) - odd_d2) / odd_d2) * 100
                df.at[idx, f"mov_{col_odd_at.replace('_atual','')}"] = mov

            # Alerta
            if ev > EV_MIN:
                time_ate = int((float(df.at[idx,"date_unix"]) - agora_ts) / 60)
                alertas.append({
                    "mercado": nome,
                    "jogo":    f"{jogo['home_team']} vs {jogo['away_team']}",
                    "liga":    jogo["league"],
                    "ev":      ev,
                    "prob":    prob,
                    "odd":     odd_at,
                    "min_ate": time_ate,
                    "mov":     ((float(odd_at)-odd_d2)/odd_d2*100) if odd_d2>0 and odd_at else 0,
                })

    df.to_csv(RODADA_CSV, index=False)

    # Exibir alertas
    if alertas:
        print(f"\n{'🚨'*3} ALERTAS DE VALOR {'🚨'*3}")
        alertas.sort(key=lambda x: x["ev"], reverse=True)
        for a in alertas:
            sinal_mov = "📉" if a["mov"] < -2 else "📈" if a["mov"] > 2 else "➡️"
            print(f"  ✅ {a['mercado']:<14} | {a['jogo']}")
            print(f"     Liga: {a['liga']} | Faltam: {a['min_ate']} min")
            print(f"     Prob={a['prob']*100:.1f}% | Odd={a['odd']} | EV={a['ev']*100:+.1f}%")
            print(f"     Movimento odd: {sinal_mov} {a['mov']:+.1f}%")
            print()
    else:
        print(f"[{agora_str}] ℹ️  Nenhum jogo com EV > {EV_MIN*100:.0f}% no momento")

    print(f"[{agora_str}] ✅ CSV atualizado → {RODADA_CSV}")

# ── Loop principal ────────────────────────────────────────────────────────────
print(f"🟢 Scheduler iniciado — atualizando a cada {INTERVALO_MIN} minutos")
print(f"   EV mínimo para alerta: {EV_MIN*100:.0f}%")
print(f"   Pressione ■ (Stop) para parar\n")

# Primeira execução imediata
atualizar_ciclo()

# Loop
ciclo = 0
while _scheduler_ativo:
    time.sleep(INTERVALO_MIN * 60)
    ciclo += 1
    print(f"\n── Ciclo {ciclo} ──────────────────────────────")
    atualizar_ciclo()
# Out:
# 🟢 Scheduler iniciado — atualizando a cada 30 minutos
#    EV mínimo para alerta: 3%
#    Pressione ■ (Stop) para parar
#
# [10:38:30] 🔄 Atualizando 207 jogos...
#
# 🚨🚨🚨 ALERTAS DE VALOR 🚨🚨🚨
#   ✅ Back Fora      | Santos vs Remo
#      Liga: Brasileiro_A Serie A | Faltam: 6261 min
#      Prob=34.7% | Odd=6.2 | EV=+115.0%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Fora      | Atlético Nacional vs Cúcuta Deportivo
#      Liga: Colombia_1 Liga BetPlay | Faltam: 5031 min
#      Prob=15.2% | Odd=13.9 | EV=+110.6%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Fora      | Cruzeiro vs Vitória
#      Liga: Brasileiro_A Serie A | Faltam: 4881 min
#      Prob=36.6% | Odd=5.5 | EV=+101.3%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Fora      | Rosario Central vs Atlético Tucumán
#      Liga: Argentina_1 Liga Profesional | Faltam: 9261 min
#      Prob=23.0% | Odd=8.45 | EV=+94.7%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Fora      | Coquimbo Unido vs Cobresal
#      Liga: Chile_1 Primera Division | Faltam: 7611 min
#      Prob=26.1% | Odd=7.15 | EV=+86.3%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Fora      | Palmeiras vs Grêmio
#      Liga: Brasileiro_A Serie A | Faltam: 6411 min
#      Prob=26.6% | Odd=6.68 | EV=+77.6%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Fora      | PAOK vs Panathinaikos
#      Liga: Grecia_1 Super League | Faltam: 7821 min
#      Prob=32.8% | Odd=5.23 | EV=+71.8%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Fora      | Huddersfield Town vs Reading
#      Liga: Inglaterra_3 League One | Faltam: 7221 min
#      Prob=37.3% | Odd=4.56 | EV=+70.2%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Fora      | Dunkerque vs Rodez
#      Liga: Franca_2 Ligue 2 | Faltam: 7461 min
#      Prob=43.8% | Odd=3.87 | EV=+69.4%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Fora      | Botafogo vs Mirassol
#      Liga: Brasileiro_A Serie A | Faltam: 4851 min
#      Prob=45.9% | Odd=3.5 | EV=+60.6%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Fora      | AZ vs Fortuna Sittard
#      Liga: Holanda_1 Eredivisie | Faltam: 8826 min
#      Prob=26.0% | Odd=6.07 | EV=+57.9%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Fora      | PSG vs Toulouse
#      Liga: Franca_1 Ligue 1 | Faltam: 7506 min
#      Prob=13.5% | Odd=10.9 | EV=+47.5%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Casa      | Adelaide United vs Auckland
#      Liga: Australia_1 A-League | Faltam: 6896 min
#      Prob=40.4% | Odd=3.62 | EV=+46.1%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Fora      | CD Castellón vs Almería
#      Liga: Espanha_2 Segunda Division | Faltam: 6021 min
#      Prob=33.5% | Odd=4.32 | EV=+44.8%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Fora      | Leicester City vs Preston North End
#      Liga: Inglaterra_2 Championship | Faltam: 7221 min
#      Prob=33.0% | Odd=4.27 | EV=+40.8%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Over 2.5       | Lanús vs Platense
#      Liga: Argentina_1 Liga Profesional | Faltam: 4881 min
#      Prob=52.7% | Odd=2.64 | EV=+39.1%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Fora      | Santa Fe vs Llaneros
#      Liga: Colombia_1 Liga BetPlay | Faltam: 4911 min
#      Prob=26.9% | Odd=5.16 | EV=+38.6%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Casa      | Vasco da Gama vs Botafogo
#      Liga: Brasileiro_A Serie A | Faltam: 9261 min
#      Prob=61.5% | Odd=2.24 | EV=+37.7%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Casa      | Bragantino vs Flamengo
#      Liga: Brasileiro_A Serie A | Faltam: 6411 min
#      Prob=33.8% | Odd=4.05 | EV=+37.1%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Fora      | Deportivo La Coruña vs Málaga CF
#      Liga: Espanha_2 Segunda Division | Faltam: 8811 min
#      Prob=36.7% | Odd=3.73 | EV=+36.9%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Fora      | Coritiba vs Vasco da Gama
#      Liga: Brasileiro_A Serie A | Faltam: 4911 min
#      Prob=41.7% | Odd=3.25 | EV=+35.5%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Fora      | Union Berlin vs St. Pauli
#      Liga: Alemanha_1 Bundesliga | Faltam: 10071 min
#      Prob=29.3% | Odd=4.57 | EV=+33.7%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Fora      | Wigan Athletic vs Leyton Orient
#      Liga: Inglaterra_3 League One | Faltam: 6066 min
#      Prob=38.5% | Odd=3.45 | EV=+32.7%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Fora      | Cherno More vs Slavia Sofia
#      Liga: Bulgaria_1 First League | Faltam: 9951 min
#      Prob=25.5% | Odd=5.16 | EV=+31.5%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Fora      | Sheffield United vs Swansea City
#      Liga: Inglaterra_2 Championship | Faltam: 7221 min
#      Prob=33.1% | Odd=3.96 | EV=+31.2%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Casa      | Beroe vs CSKA Sofia
#      Liga: Bulgaria_1 First League | Faltam: 8811 min
#      Prob=13.0% | Odd=10 | EV=+30.4%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Fora      | Luton Town vs Peterborough United
#      Liga: Inglaterra_3 League One | Faltam: 7221 min
#      Prob=29.0% | Odd=4.5 | EV=+30.4%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Fora      | Alianza Petrolera vs Deportivo Pasto
#      Liga: Colombia_1 Liga BetPlay | Faltam: 4771 min
#      Prob=49.6% | Odd=2.62 | EV=+29.9%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Fora      | Almería vs Real Sociedad II
#      Liga: Espanha_2 Segunda Division | Faltam: 321 min
#      Prob=26.2% | Odd=4.95 | EV=+29.9%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Fora      | West Bromwich Albion vs Wrexham
#      Liga: Inglaterra_2 Championship | Faltam: 7221 min
#      Prob=43.9% | Odd=2.96 | EV=+29.8%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Fora      | Independiente Medellín vs América de Cali
#      Liga: Colombia_1 Liga BetPlay | Faltam: 2011 min
#      Prob=40.4% | Odd=3.2 | EV=+29.1%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Fora      | Deportes Tolima vs Rionegro Águilas
#      Liga: Colombia_1 Liga BetPlay | Faltam: 3561 min
#      Prob=24.4% | Odd=5.3 | EV=+29.1%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Casa      | Talleres Córdoba vs Boca Juniors
#      Liga: Argentina_1 Liga Profesional | Faltam: 6351 min
#      Prob=39.5% | Odd=3.26 | EV=+28.9%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Over 2.5       | Lazio vs Parma
#      Liga: Italia_1 Serie A | Faltam: 8946 min
#      Prob=58.2% | Odd=2.2 | EV=+28.1%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Over 2.5       | Levadiakos vs Aris
#      Liga: Grecia_1 Super League | Faltam: 7821 min
#      Prob=58.1% | Odd=2.2 | EV=+27.8%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Fora      | FC Andorra vs Málaga CF
#      Liga: Espanha_2 Segunda Division | Faltam: 4521 min
#      Prob=46.4% | Odd=2.74 | EV=+27.1%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Fora      | Lanús vs Platense
#      Liga: Argentina_1 Liga Profesional | Faltam: 4881 min
#      Prob=28.5% | Odd=4.44 | EV=+26.6%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Fora      | PSV vs Utrecht
#      Liga: Holanda_1 Eredivisie | Faltam: 8691 min
#      Prob=17.2% | Odd=7.35 | EV=+26.4%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Fora      | Hamburger SV vs Augsburg
#      Liga: Alemanha_1 Bundesliga | Faltam: 8631 min
#      Prob=37.0% | Odd=3.41 | EV=+26.0%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Over 2.5       | Bahia vs Atlético PR
#      Liga: Brasileiro_A Serie A | Faltam: 4881 min
#      Prob=60.0% | Odd=2.1 | EV=+26.0%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Over 2.5       | Independiente vs Racing Club
#      Liga: Argentina_1 Liga Profesional | Faltam: 9051 min
#      Prob=51.3% | Odd=2.45 | EV=+25.7%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Over 2.5       | Aldosivi vs Argentinos Juniors
#      Liga: Argentina_1 Liga Profesional | Faltam: 3081 min
#      Prob=50.0% | Odd=2.51 | EV=+25.6%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Fora      | Porto vs Famalicão
#      Liga: Portugal_1 Primeira Liga | Faltam: 8991 min
#      Prob=13.9% | Odd=8.99 | EV=+25.3%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Fora      | Stuttgart vs Borussia Dortmund
#      Liga: Alemanha_1 Bundesliga | Faltam: 8811 min
#      Prob=40.6% | Odd=3.09 | EV=+25.3%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Over 2.5       | Red Star vs Laval
#      Liga: Franca_2 Ligue 2 | Faltam: 7461 min
#      Prob=59.2% | Odd=2.1 | EV=+24.4%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Over 2.5       | Norwich City vs Portsmouth
#      Liga: Inglaterra_2 Championship | Faltam: 7221 min
#      Prob=62.7% | Odd=1.98 | EV=+24.2%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Over 2.5       | Alianza Petrolera vs Deportivo Pasto
#      Liga: Colombia_1 Liga BetPlay | Faltam: 4771 min
#      Prob=50.2% | Odd=2.47 | EV=+24.0%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Over 2.5       | Internacional vs São Paulo
#      Liga: Brasileiro_A Serie A | Faltam: 4851 min
#      Prob=57.4% | Odd=2.15 | EV=+23.5%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Fora      | Lille vs Lens
#      Liga: Franca_1 Ligue 1 | Faltam: 8966 min
#      Prob=42.4% | Odd=2.89 | EV=+22.7%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ BTTS           | Aldosivi vs Argentinos Juniors
#      Liga: Argentina_1 Liga Profesional | Faltam: 3081 min
#      Prob=55.2% | Odd=2.22 | EV=+22.5%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Fora      | Birmingham City vs Blackburn Rovers
#      Liga: Inglaterra_2 Championship | Faltam: 7221 min
#      Prob=25.0% | Odd=4.9 | EV=+22.5%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Fora      | Rotherham United vs Stevenage
#      Liga: Inglaterra_3 League One | Faltam: 7221 min
#      Prob=52.0% | Odd=2.35 | EV=+22.3%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Casa      | Volendam vs Feyenoord
#      Liga: Holanda_1 Eredivisie | Faltam: 10011 min
#      Prob=19.8% | Odd=6.17 | EV=+22.0%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Over 2.5       | Botafogo vs Mirassol
#      Liga: Brasileiro_A Serie A | Faltam: 4851 min
#      Prob=56.7% | Odd=2.15 | EV=+21.8%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Fora      | Unión Santa Fe vs Deportivo Riestra
#      Liga: Argentina_1 Liga Profesional | Faltam: 7596 min
#      Prob=21.9% | Odd=5.55 | EV=+21.8%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Casa      | Cremonese vs Bologna
#      Liga: Italia_1 Serie A | Faltam: 10041 min
#      Prob=29.0% | Odd=4.19 | EV=+21.6%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Fora      | Middlesbrough vs Millwall
#      Liga: Inglaterra_2 Championship | Faltam: 7071 min
#      Prob=25.6% | Odd=4.75 | EV=+21.5%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Fora      | Cultural y Deportiva Leonesa vs FC Andorra
#      Liga: Espanha_2 Segunda Division | Faltam: 36 min
#      Prob=44.9% | Odd=2.7 | EV=+21.2%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Fora      | Gil Vicente vs AVS
#      Liga: Portugal_1 Primeira Liga | Faltam: 7251 min
#      Prob=13.3% | Odd=9.07 | EV=+20.6%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Over 2.5       | Burgos CF vs Ceuta
#      Liga: Espanha_2 Segunda Division | Faltam: 4581 min
#      Prob=56.3% | Odd=2.14 | EV=+20.5%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Fora      | San Lorenzo vs Estudiantes
#      Liga: Argentina_1 Liga Profesional | Faltam: 7731 min
#      Prob=46.5% | Odd=2.59 | EV=+20.5%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Fora      | Lazio vs Parma
#      Liga: Italia_1 Serie A | Faltam: 8946 min
#      Prob=23.5% | Odd=5.11 | EV=+20.2%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Casa      | Charlton Athletic vs Bristol City
#      Liga: Inglaterra_2 Championship | Faltam: 7221 min
#      Prob=44.8% | Odd=2.68 | EV=+20.1%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Casa      | Angers SCO vs Olympique Lyonnais
#      Liga: Franca_1 Ligue 1 | Faltam: 10041 min
#      Prob=26.2% | Odd=4.57 | EV=+19.9%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ BTTS           | Lanús vs Platense
#      Liga: Argentina_1 Liga Profesional | Faltam: 4881 min
#      Prob=54.4% | Odd=2.2 | EV=+19.8%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Over 2.5       | Tigre vs Independiente Rivadavia
#      Liga: Argentina_1 Liga Profesional | Faltam: 6171 min
#      Prob=51.0% | Odd=2.35 | EV=+19.8%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Fora      | Excelsior vs NEC
#      Liga: Holanda_1 Eredivisie | Faltam: 8961 min
#      Prob=63.2% | Odd=1.89 | EV=+19.4%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Fora      | Tigre vs Independiente Rivadavia
#      Liga: Argentina_1 Liga Profesional | Faltam: 6171 min
#      Prob=36.7% | Odd=3.25 | EV=+19.3%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Over 2.5       | Coritiba vs Vasco da Gama
#      Liga: Brasileiro_A Serie A | Faltam: 4911 min
#      Prob=56.7% | Odd=2.1 | EV=+19.1%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Fora      | Sporting CP vs Santa Clara
#      Liga: Portugal_1 Primeira Liga | Faltam: 7551 min
#      Prob=8.2% | Odd=14.5 | EV=+19.0%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Fora      | Coventry City vs Derby County
#      Liga: Inglaterra_2 Championship | Faltam: 7521 min
#      Prob=18.4% | Odd=6.46 | EV=+18.8%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Fora      | Boyacá Chicó vs Deportivo Pereira
#      Liga: Colombia_1 Liga BetPlay | Faltam: 6081 min
#      Prob=31.2% | Odd=3.79 | EV=+18.1%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Fora      | Zulte-Waregem vs Cercle Brugge
#      Liga: Belgica_1 Pro League | Faltam: 8661 min
#      Prob=37.4% | Odd=3.15 | EV=+18.0%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Over 2.5       | SD Huesca vs Cultural y Deportiva Leonesa
#      Liga: Espanha_2 Segunda Division | Faltam: 4581 min
#      Prob=55.9% | Odd=2.1 | EV=+17.4%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Fora      | Stockport County vs Wycombe Wanderers
#      Liga: Inglaterra_3 League One | Faltam: 7221 min
#      Prob=34.5% | Odd=3.4 | EV=+17.3%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Casa      | Chapecoense vs Atlético Mineiro
#      Liga: Brasileiro_A Serie A | Faltam: 6261 min
#      Prob=38.2% | Odd=3.07 | EV=+17.3%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Fora      | Real Zaragoza vs Racing Santander
#      Liga: Espanha_2 Segunda Division | Faltam: 171 min
#      Prob=50.7% | Odd=2.31 | EV=+17.1%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Over 2.5       | Hellas Verona vs Fiorentina
#      Liga: Italia_1 Serie A | Faltam: 8781 min
#      Prob=55.7% | Odd=2.1 | EV=+17.0%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Fora      | Cádiz vs Córdoba
#      Liga: Espanha_2 Segunda Division | Faltam: 8541 min
#      Prob=46.4% | Odd=2.52 | EV=+16.9%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Over 2.5       | West Bromwich Albion vs Wrexham
#      Liga: Inglaterra_2 Championship | Faltam: 7221 min
#      Prob=56.7% | Odd=2.05 | EV=+16.3%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Fora      | Bahia vs Atlético PR
#      Liga: Brasileiro_A Serie A | Faltam: 4881 min
#      Prob=27.8% | Odd=4.16 | EV=+15.7%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Fora      | CD Nacional vs Estrela Amadora
#      Liga: Portugal_1 Primeira Liga | Faltam: 8691 min
#      Prob=31.7% | Odd=3.64 | EV=+15.5%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Over 2.5       | Cruzeiro vs Vitória
#      Liga: Brasileiro_A Serie A | Faltam: 4881 min
#      Prob=55.8% | Odd=2.07 | EV=+15.4%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Fora      | Go Ahead Eagles vs PEC Zwolle
#      Liga: Holanda_1 Eredivisie | Faltam: 9876 min
#      Prob=33.0% | Odd=3.5 | EV=+15.4%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Over 2.5       | Bastia vs Amiens SC
#      Liga: Franca_2 Ligue 2 | Faltam: 7461 min
#      Prob=56.2% | Odd=2.05 | EV=+15.3%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Over 2.5       | Grenoble Foot 38 vs Clermont
#      Liga: Franca_2 Ligue 2 | Faltam: 7461 min
#      Prob=56.2% | Odd=2.05 | EV=+15.2%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Fora      | Burton Albion vs Barnsley
#      Liga: Inglaterra_3 League One | Faltam: 7221 min
#      Prob=35.5% | Odd=3.24 | EV=+15.2%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ BTTS           | Atlético Nacional vs Cúcuta Deportivo
#      Liga: Colombia_1 Liga BetPlay | Faltam: 5031 min
#      Prob=54.4% | Odd=2.11 | EV=+14.9%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Fora      | Montpellier vs Troyes
#      Liga: Franca_2 Ligue 2 | Faltam: 8541 min
#      Prob=46.9% | Odd=2.45 | EV=+14.8%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Casa      | Brisbane Roar vs Sydney FC
#      Liga: Australia_1 A-League | Faltam: 5541 min
#      Prob=32.4% | Odd=3.54 | EV=+14.6%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Over 2.5       | Annecy vs Guingamp
#      Liga: Franca_2 Ligue 2 | Faltam: 7461 min
#      Prob=55.9% | Odd=2.05 | EV=+14.6%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Fora      | Mirandés vs Albacete Balompié
#      Liga: Espanha_2 Segunda Division | Faltam: 3081 min
#      Prob=45.8% | Odd=2.5 | EV=+14.4%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Over 2.5       | Birmingham City vs Blackburn Rovers
#      Liga: Inglaterra_2 Championship | Faltam: 7221 min
#      Prob=57.8% | Odd=1.98 | EV=+14.4%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Casa      | Grenoble Foot 38 vs Clermont
#      Liga: Franca_2 Ligue 2 | Faltam: 7461 min
#      Prob=46.3% | Odd=2.47 | EV=+14.3%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Fora      | Oxford United vs Hull City
#      Liga: Inglaterra_2 Championship | Faltam: 7221 min
#      Prob=43.8% | Odd=2.61 | EV=+14.3%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Fora      | Brest vs Rennes
#      Liga: Franca_1 Ligue 1 | Faltam: 8841 min
#      Prob=44.4% | Odd=2.57 | EV=+14.1%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Fora      | Livingston vs Hearts
#      Liga: Escocia_1 Premiership | Faltam: 10041 min
#      Prob=75.5% | Odd=1.51 | EV=+13.9%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Over 2.5       | Santa Fe vs Llaneros
#      Liga: Colombia_1 Liga BetPlay | Faltam: 4911 min
#      Prob=54.8% | Odd=2.08 | EV=+13.9%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Fora      | Borussia M'gladbach vs Heidenheim
#      Liga: Alemanha_1 Bundesliga | Faltam: 8631 min
#      Prob=19.6% | Odd=5.79 | EV=+13.6%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Fora      | Hoffenheim vs Mainz 05
#      Liga: Alemanha_1 Bundesliga | Faltam: 8631 min
#      Prob=22.6% | Odd=5.02 | EV=+13.6%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Fora      | Nancy vs Saint-Étienne
#      Liga: Franca_2 Ligue 2 | Faltam: 8901 min
#      Prob=57.1% | Odd=1.99 | EV=+13.6%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Over 2.5       | Chapecoense vs Atlético Mineiro
#      Liga: Brasileiro_A Serie A | Faltam: 6261 min
#      Prob=54.0% | Odd=2.1 | EV=+13.4%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Over 2.5       | PAOK vs Panathinaikos
#      Liga: Grecia_1 Super League | Faltam: 7821 min
#      Prob=55.3% | Odd=2.05 | EV=+13.3%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Fora      | Gimnasia Mendoza vs Vélez Sarsfield
#      Liga: Argentina_1 Liga Profesional | Faltam: 7461 min
#      Prob=49.4% | Odd=2.28 | EV=+12.7%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Over 2.5       | Vasco da Gama vs Botafogo
#      Liga: Brasileiro_A Serie A | Faltam: 9261 min
#      Prob=54.8% | Odd=2.05 | EV=+12.4%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Casa      | Central Coast Mariners vs Perth Glory FC
#      Liga: Australia_1 A-League | Faltam: 8181 min
#      Prob=45.7% | Odd=2.46 | EV=+12.4%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Over 2.5       | Sporting CP vs Santa Clara
#      Liga: Portugal_1 Primeira Liga | Faltam: 7551 min
#      Prob=60.6% | Odd=1.85 | EV=+12.2%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Over 2.5       | Charlton Athletic vs Bristol City
#      Liga: Inglaterra_2 Championship | Faltam: 7221 min
#      Prob=54.7% | Odd=2.05 | EV=+12.2%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Over 2.5       | Real Valladolid vs Cádiz
#      Liga: Espanha_2 Segunda Division | Faltam: 3231 min
#      Prob=61.4% | Odd=1.82 | EV=+11.7%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Over 2.5       | Fluminense vs Corinthians
#      Liga: Brasileiro_A Serie A | Faltam: 4971 min
#      Prob=54.3% | Odd=2.05 | EV=+11.3%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Over 2.5       | Independiente Medellín vs América de Cali
#      Liga: Colombia_1 Liga BetPlay | Faltam: 2011 min
#      Prob=52.4% | Odd=2.12 | EV=+11.0%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Casa      | São Paulo vs Cruzeiro
#      Liga: Brasileiro_A Serie A | Faltam: 9111 min
#      Prob=49.8% | Odd=2.22 | EV=+10.6%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ BTTS           | Millonarios vs Fortaleza CEIF
#      Liga: Colombia_1 Liga BetPlay | Faltam: 2141 min
#      Prob=53.9% | Odd=2.05 | EV=+10.4%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Casa      | Moreirense FC vs Sporting Braga
#      Liga: Portugal_1 Primeira Liga | Faltam: 8841 min
#      Prob=17.1% | Odd=6.46 | EV=+10.4%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Fora      | Burgos CF vs Ceuta
#      Liga: Espanha_2 Segunda Division | Faltam: 4581 min
#      Prob=26.2% | Odd=4.2 | EV=+10.2%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Casa      | Lincoln City vs AFC Wimbledon
#      Liga: Inglaterra_3 League One | Faltam: 7221 min
#      Prob=74.9% | Odd=1.47 | EV=+10.1%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Fora      | Strasbourg vs Nice
#      Liga: Franca_1 Ligue 1 | Faltam: 8721 min
#      Prob=20.5% | Odd=5.38 | EV=+10.0%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Over 2.5       | Atlético PR vs Botafogo
#      Liga: Brasileiro_A Serie A | Faltam: 531 min
#      Prob=51.9% | Odd=2.12 | EV=+9.9%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Over 2.5       | Brest vs Rennes
#      Liga: Franca_1 Ligue 1 | Faltam: 8841 min
#      Prob=61.7% | Odd=1.78 | EV=+9.9%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ BTTS           | Alianza Petrolera vs Deportivo Pasto
#      Liga: Colombia_1 Liga BetPlay | Faltam: 4771 min
#      Prob=54.3% | Odd=2.02 | EV=+9.7%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Fora      | Vitória Guimarães vs CD Tondela
#      Liga: Portugal_1 Primeira Liga | Faltam: 7401 min
#      Prob=21.9% | Odd=5 | EV=+9.5%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Over 2.5       | Real Zaragoza vs Racing Santander
#      Liga: Espanha_2 Segunda Division | Faltam: 171 min
#      Prob=53.1% | Odd=2.06 | EV=+9.4%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Fora      | Real Valladolid vs Cádiz
#      Liga: Espanha_2 Segunda Division | Faltam: 3231 min
#      Prob=27.3% | Odd=4 | EV=+9.2%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Over 2.5       | Oxford United vs Hull City
#      Liga: Inglaterra_2 Championship | Faltam: 7221 min
#      Prob=55.2% | Odd=1.98 | EV=+9.2%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ BTTS           | Santa Fe vs Llaneros
#      Liga: Colombia_1 Liga BetPlay | Faltam: 4911 min
#      Prob=54.0% | Odd=2.02 | EV=+9.0%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Over 2.5       | Cultural y Deportiva Leonesa vs FC Andorra
#      Liga: Espanha_2 Segunda Division | Faltam: 36 min
#      Prob=50.6% | Odd=2.15 | EV=+8.8%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Over 2.5       | Rio Ave FC vs Alverca
#      Liga: Portugal_1 Primeira Liga | Faltam: 8841 min
#      Prob=53.0% | Odd=2.05 | EV=+8.7%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ BTTS           | Cruzeiro vs Vitória
#      Liga: Brasileiro_A Serie A | Faltam: 4881 min
#      Prob=53.5% | Odd=2.03 | EV=+8.7%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Fora      | Sassuolo vs Cagliari
#      Liga: Italia_1 Serie A | Faltam: 8601 min
#      Prob=22.4% | Odd=4.86 | EV=+8.7%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Over 2.5       | Queens Park Rangers vs Watford
#      Liga: Inglaterra_2 Championship | Faltam: 7221 min
#      Prob=55.7% | Odd=1.95 | EV=+8.6%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Over 2.5       | Sheffield United vs Swansea City
#      Liga: Inglaterra_2 Championship | Faltam: 7221 min
#      Prob=58.6% | Odd=1.85 | EV=+8.4%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Casa      | Rio Ave FC vs Alverca
#      Liga: Portugal_1 Primeira Liga | Faltam: 8841 min
#      Prob=42.6% | Odd=2.54 | EV=+8.2%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Casa      | Hellas Verona vs Fiorentina
#      Liga: Italia_1 Serie A | Faltam: 8781 min
#      Prob=24.9% | Odd=4.35 | EV=+8.1%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Over 2.5       | Coquimbo Unido vs Cobresal
#      Liga: Chile_1 Primera Division | Faltam: 7611 min
#      Prob=62.8% | Odd=1.72 | EV=+7.9%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Over 2.5       | Real Betis vs RCD Espanyol
#      Liga: Espanha_1 La Liga | Faltam: 8811 min
#      Prob=56.7% | Odd=1.9 | EV=+7.8%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Over 2.5       | Lincoln City vs AFC Wimbledon
#      Liga: Inglaterra_3 League One | Faltam: 7221 min
#      Prob=59.1% | Odd=1.82 | EV=+7.6%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Over 2.5       | Zalaegerszegi TE vs Várda SE
#      Liga: Hungria_1 NB I | Faltam: 8571 min
#      Prob=55.3% | Odd=1.94 | EV=+7.4%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Casa      | Real Sociedad II vs SD Eibar
#      Liga: Espanha_2 Segunda Division | Faltam: 6021 min
#      Prob=38.2% | Odd=2.81 | EV=+7.3%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Over 2.5       | Cremonese vs Bologna
#      Liga: Italia_1 Serie A | Faltam: 10041 min
#      Prob=54.1% | Odd=1.98 | EV=+7.1%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Over 2.5       | Gil Vicente vs AVS
#      Liga: Portugal_1 Primeira Liga | Faltam: 7251 min
#      Prob=56.4% | Odd=1.9 | EV=+7.1%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Over 2.5       | Sassuolo vs Cagliari
#      Liga: Italia_1 Serie A | Faltam: 8601 min
#      Prob=49.7% | Odd=2.15 | EV=+6.8%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Fora      | Werder Bremen vs RB Leipzig
#      Liga: Alemanha_1 Bundesliga | Faltam: 8631 min
#      Prob=50.1% | Odd=2.13 | EV=+6.7%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Casa      | Motherwell vs Falkirk
#      Liga: Escocia_1 Premiership | Faltam: 8661 min
#      Prob=58.6% | Odd=1.82 | EV=+6.7%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ BTTS           | Fluminense vs Corinthians
#      Liga: Brasileiro_A Serie A | Faltam: 4971 min
#      Prob=53.0% | Odd=2.01 | EV=+6.5%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ BTTS           | Botafogo vs Mirassol
#      Liga: Brasileiro_A Serie A | Faltam: 4851 min
#      Prob=57.2% | Odd=1.86 | EV=+6.4%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Fora      | Union Saint-Gilloise vs Sint-Truiden
#      Liga: Belgica_1 Pro League | Faltam: 8946 min
#      Prob=22.4% | Odd=4.74 | EV=+6.3%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Fora      | Aldosivi vs Argentinos Juniors
#      Liga: Argentina_1 Liga Profesional | Faltam: 3081 min
#      Prob=53.6% | Odd=1.98 | EV=+6.2%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Casa      | Bayer Leverkusen vs Wolfsburg
#      Liga: Alemanha_1 Bundesliga | Faltam: 8631 min
#      Prob=70.2% | Odd=1.51 | EV=+6.1%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Casa      | Telstar vs Groningen
#      Liga: Holanda_1 Eredivisie | Faltam: 8826 min
#      Prob=36.4% | Odd=2.91 | EV=+5.9%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ BTTS           | Burgos CF vs Ceuta
#      Liga: Espanha_2 Segunda Division | Faltam: 4581 min
#      Prob=55.4% | Odd=1.91 | EV=+5.8%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Fora      | Millonarios vs Fortaleza CEIF
#      Liga: Colombia_1 Liga BetPlay | Faltam: 2141 min
#      Prob=20.1% | Odd=5.25 | EV=+5.8%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Casa      | Freiburg vs Bayern München
#      Liga: Alemanha_1 Bundesliga | Faltam: 8631 min
#      Prob=13.1% | Odd=8.1 | EV=+5.7%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ BTTS           | Coritiba vs Vasco da Gama
#      Liga: Brasileiro_A Serie A | Faltam: 4911 min
#      Prob=57.0% | Odd=1.85 | EV=+5.4%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ BTTS           | Deportes Tolima vs Rionegro Águilas
#      Liga: Colombia_1 Liga BetPlay | Faltam: 3561 min
#      Prob=53.4% | Odd=1.97 | EV=+5.2%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Fora      | Hibernian vs Kilmarnock
#      Liga: Escocia_1 Premiership | Faltam: 8661 min
#      Prob=16.4% | Odd=6.4 | EV=+4.8%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Over 2.5       | Beroe vs CSKA Sofia
#      Liga: Bulgaria_1 First League | Faltam: 8811 min
#      Prob=52.9% | Odd=1.98 | EV=+4.7%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Casa      | Deportivo Pasto vs Atlético Nacional
#      Liga: Colombia_1 Liga BetPlay | Faltam: 581 min
#      Prob=35.6% | Odd=2.94 | EV=+4.7%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Over 2.5       | Palmeiras vs Grêmio
#      Liga: Brasileiro_A Serie A | Faltam: 6411 min
#      Prob=58.1% | Odd=1.8 | EV=+4.6%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Casa      | Heerenveen vs Heracles
#      Liga: Holanda_1 Eredivisie | Faltam: 10011 min
#      Prob=71.1% | Odd=1.47 | EV=+4.5%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Fora      | Coritiba vs Fluminense
#      Liga: Brasileiro_A Serie A | Faltam: 9231 min
#      Prob=43.8% | Odd=2.38 | EV=+4.3%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Over 2.5       | Montpellier vs Troyes
#      Liga: Franca_2 Ligue 2 | Faltam: 8541 min
#      Prob=57.5% | Odd=1.81 | EV=+4.1%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Fora      | Royal Antwerp FC vs KRC Genk
#      Liga: Belgica_1 Pro League | Faltam: 7506 min
#      Prob=45.2% | Odd=2.3 | EV=+3.9%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Over 2.5       | La Equidad vs Junior
#      Liga: Colombia_1 Liga BetPlay | Faltam: 451 min
#      Prob=50.9% | Odd=2.04 | EV=+3.9%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Fora      | Jaguares de Córdoba vs Millonarios
#      Liga: Colombia_1 Liga BetPlay | Faltam: 6341 min
#      Prob=56.2% | Odd=1.85 | EV=+3.9%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Over 2.5       | Volos NFC vs OFI
#      Liga: Grecia_1 Super League | Faltam: 7821 min
#      Prob=49.3% | Odd=2.1 | EV=+3.6%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Fora      | Llaneros vs Once Caldas
#      Liga: Colombia_1 Liga BetPlay | Faltam: 711 min
#      Prob=43.1% | Odd=2.4 | EV=+3.4%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Over 2.5       | Angers SCO vs Olympique Lyonnais
#      Liga: Franca_1 Ligue 1 | Faltam: 10041 min
#      Prob=49.1% | Odd=2.1 | EV=+3.2%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Casa      | Arda vs Montana
#      Liga: Bulgaria_1 First League | Faltam: 8511 min
#      Prob=70.1% | Odd=1.47 | EV=+3.1%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Fora      | Albacete Balompié vs Burgos CF
#      Liga: Espanha_2 Segunda Division | Faltam: 8676 min
#      Prob=31.1% | Odd=3.31 | EV=+3.0%
#      Movimento odd: ➡️ +0.0%
#
#   ✅ Back Casa      | Red Star vs Laval
#      Liga: Franca_2 Ligue 2 | Faltam: 7461 min
#      Prob=59.9% | Odd=1.72 | EV=+3.0%
#      Movimento odd: ➡️ +0.0%
#
# [10:38:30] ✅ CSV atualizado → rodada_atual_v3.csv

# %%
# ── Parar o scheduler ────────────────────────────────────────────────────────
# Rode esta célula para parar o loop sem precisar reiniciar o kernel
_scheduler_ativo = False
print("🔴 Scheduler parado")
